# %% [markdown]
# # Your Uni : xh2604 and mm6712
# # Your Full name : Xiyun Hu and Mathis Mallet
# # Link to your Public Github repository with Final report  : https://github.com/MathisMallet/Advanced-Machine-Learning

# %% [markdown]
# # World Happiness Classification Competition
# Goals :
# - Understand how the models function
# - Understand what the parameters control
# - Learn from the model experimentation process
# - Make a good looking notebook report
# - Upload as a personal project on Github
#
# **Overall Steps:**
# 1. Get data in and set up X_train / X_test / y_train
# 2. Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit predictions

# %% [markdown]
# ## 0. Get data in and set up X_train, X_test, y_train objects

# %% [markdown]
# Upload the world_happiness_competition_data.zip and newcountryvars.csv files on Colab by pressing the Folder icon on left tab (Shows "Files" on hovering), and then clicking the left-most file upload button (Shows "Upload to Session Storage" Alt text on hovering)

# %%
# Get training data from course folder and unzip
# importing the zipfile module
from zipfile import ZipFile
import os


# loading the temp.zip and creating a zip object
with ZipFile("world_happiness_competition_data.zip", 'r') as zObject:

    # Extracting all the members of the zip
    # into a specific location.
    zObject.extractall()

# %%
# Load data
import pandas as pd
X_train = pd.read_csv('world_happiness_competition_data\\X_train.csv') # Load train features to train on
X_test =  pd.read_csv("world_happiness_competition_data\\X_test.csv") # Load test features to predict on
y_train =  pd.read_csv("world_happiness_competition_data\\y_train.csv") # Load y train (true labels)
y_test =  pd.read_csv("world_happiness_competition_data\\y_test.csv") # Load y test (true labels)
y_train_labels = y_train.idxmax(axis=1) # Examine what this does and write in next cell
y_test_labels = y_test.idxmax(axis=1) # Complete in a similar manner as above

X_train.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0            Latvia           1.187           1.465                    0.812
# 1           Burundi           0.046           0.447                    0.380
# 2           Belarus           1.067           1.465                    0.789
# 3           Liberia           0.073           0.922                    0.443
# 4           Ecuador           0.912           1.312                    0.868
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.264       0.075                      0.064
# 1                         0.220       0.176                      0.180
# 2                         0.235       0.094                      0.142
# 3                         0.370       0.233                      0.033
# 4                         0.498       0.126                      0.087
#
#       name    region                       sub-region  Terrorist_attacks
# 0   Latvia    Europe                  Northern Europe         125.611111
# 1  Burundi    Africa               Sub-Saharan Africa         155.000000
# 2  Belarus    Europe                   Eastern Europe           4.000000
# 3  Liberia    Africa               Sub-Saharan Africa        1419.095238
# 4  Ecuador  Americas  Latin America and the Caribbean           5.000000

# %% [markdown]
# ##  Add new data

# %%
# Truncated and cleaned up region data to merge
countrydata=pd.read_csv("newcountryvars.csv")

countrydata.head()
# Out:
#   country_name  population  population_below_poverty_line       hdi  \
# 0        India  1339180127                           21.9  0.623559
# 1      Nigeria   190886311                           70.0  0.527105
# 2       Mexico   129163276                           46.2  0.761683
# 3     Pakistan   197015955                           29.5  0.550354
# 4   Bangladesh   164669751                           31.5  0.578824
#
#    life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0           68.322                    11.696590                 6.298834
# 1           53.057                     9.970482                 6.000000
# 2           76.972                    13.299090                 8.554985
# 3           66.365                     8.106910                 5.089460
# 4           71.985                    10.178706                 5.241577
#
#             gni
# 0   5663.474799
# 1   5442.901264
# 2  16383.106680
# 3   5031.173074
# 4   3341.490722

# %%
# Merge in new data to X_train and X_test by taking "Country or region" from first table and "country_name" from 2nd table.

X_train = pd.merge(X_train, countrydata, left_on="Country or region", right_on="country_name", how='left') #We remove 6 countries without enough data
X_test = pd.merge(X_test, countrydata, left_on="Country or region", right_on="country_name", how='left')
X_train = X_train.drop(columns =["country_name"])
X_test = X_test.drop(columns =["country_name"])

# %%
X_train.head(1)
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0            Latvia           1.187           1.465                    0.812
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.264       0.075                      0.064
#
#      name  region       sub-region  Terrorist_attacks  population  \
# 0  Latvia  Europe  Northern Europe         125.611111   1949670.0
#
#    population_below_poverty_line       hdi  life_expectancy  \
# 0                           25.5  0.829862           74.342
#
#    expected_years_of_schooling  mean_years_of_schooling          gni
# 0                     15.97411                11.736418  22589.17355

# %% [markdown]
# # EDA

# %%
print(X_train.dtypes)
# Out:
# Country or region                 object
# GDP per capita                   float64
# Social support                   float64
# Healthy life expectancy          float64
# Freedom to make life choices     float64
# Generosity                       float64
# Perceptions of corruption        float64
# name                              object
# region                            object
# sub-region                        object
# Terrorist_attacks                float64
# population                       float64
# population_below_poverty_line    float64
# hdi                              float64
# life_expectancy                  float64
# expected_years_of_schooling      float64
# mean_years_of_schooling          float64
# gni                              float64
# dtype: object

# %% [markdown]
# **Find out the number and percentage of missing values in the table per column**

# %%
print("Training data missing values (%)")
print(X_train.isnull().sum()/(len(X_train))*100, "\n")
print("Testing data missing values (%)")
print(X_test.isnull().sum()/(len(X_test))*100)
# Out:
# Training data missing values (%)
# Country or region                 0.000000
# GDP per capita                    0.000000
# Social support                    0.000000
# Healthy life expectancy           0.000000
# Freedom to make life choices      0.000000
# Generosity                        0.000000
# Perceptions of corruption         0.000000
# name                              0.000000
# region                            0.000000
# sub-region                        0.000000
# Terrorist_attacks                 0.000000
# population                        8.695652
# population_below_poverty_line    15.942029
# hdi                               8.695652
# life_expectancy                   8.695652
# expected_years_of_schooling       8.695652
# mean_years_of_schooling           8.695652
# gni                               8.695652
# dtype: float64
#
# Testing data missing values (%)
# Country or region                 0.000000
# GDP per capita                    0.000000
# Social support                    0.000000
# Healthy life expectancy           0.000000
# Freedom to make life choices      0.000000
# Generosity                        0.000000
# Perceptions of corruption         0.000000
# name                              0.000000
# region                            0.000000
# sub-region                        0.000000
# Terrorist_attacks                 0.000000
# population                        0.000000
# population_below_poverty_line    21.052632
# hdi                               0.000000
# life_expectancy                   0.000000
# expected_years_of_schooling       0.000000
# mean_years_of_schooling           0.000000
# gni                               0.000000
# dtype: float64

# %% [markdown]
# **Plot the frequency distribution / histogram of some of the numerical features that you think are important**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# figure initialization
plt.figure(figsize=(12, 6))

# 'GDP per capita' histogram
plt.subplot(1, 3, 1)
sns.histplot(X_train["GDP per capita"], bins=10, kde=True, stat="percent")
plt.title("GDP per capita histogram")

# "Healthy life expectancy" histogram
plt.subplot(1, 3, 2)
sns.histplot(X_train["Healthy life expectancy"], bins=10, kde=True, stat="percent")
plt.title("Healthy life expectancy histogram")

# "Social support" histogram
plt.subplot(1, 3, 3)
sns.histplot(X_train['Social support'], bins=10, kde=True, stat="percent")
plt.title('Social support')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Plot the categorical variables and their distribution**

# %%
# figure initialization
plt.figure(figsize=(12, 6))

# "Social support" histogram
plt.subplot(1, 2, 1)
sns.countplot(x="region", data= X_train)
plt.title('region distribution')

# "sub-region" histogram
plt.subplot(1, 2, 2)
sns.countplot(x="sub-region", data= X_train)
plt.xticks(rotation=90)
plt.title('sub-region distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Explore relationships between variables (bivariate, etc), correlation tables, and how they associate with the target variable.**

# %%
#Correlation Matrix
X_train_num = X_train.select_dtypes(exclude=['object'])
correlation_matrix = X_train_num.corr()
#Ploting of the matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".1f", cmap='viridis', square=True)
plt.title('Correlation Matrix')
plt.show()

# Bivariate analysis
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.scatterplot(x="GDP per capita", y="Healthy life expectancy", data= X_train_num)
plt.title("Healthy life expectancy vs GDP per capita")
plt.subplot(1, 2, 2)
sns.scatterplot(x="Social support", y="population_below_poverty_line", data= X_train_num)
plt.title("population_below_poverty_line vs Social support")

plt.tight_layout()
plt.show()

#Grouped analysis
X_train_temp = X_train_num
X_train_temp["Happiness"] = y_train_labels
grouped_means = X_train_temp.groupby("Happiness").mean()
print(grouped_means)
# Out:
#            GDP per capita  Social support  Healthy life expectancy  \
# Happiness
# Average          0.978231        1.238769                 0.817000
# High             1.111353        1.394176                 0.851706
# Low              0.764333        1.092417                 0.599583
# Very High        1.400385        1.479923                 0.985077
# Very Low         0.393071        0.910571                 0.464857
#
#            Freedom to make life choices  Generosity  \
# Happiness
# Average                        0.305538    0.160231
# High                           0.409824    0.139941
# Low                            0.328083    0.144750
# Very High                      0.539000    0.250769
# Very Low                       0.248929    0.228357
#
#            Perceptions of corruption  Terrorist_attacks    population  \
# Happiness
# Average                     0.090615         278.484950  1.607969e+08
# High                        0.065412          57.545752  1.602114e+07
# Low                         0.073583          82.583333  2.822797e+07
# Very High                   0.245923          25.461538  1.333097e+07
# Very Low                    0.084214        1043.105442  3.050687e+07
#
#            population_below_poverty_line       hdi  life_expectancy  \
# Happiness
# Average                        17.718182  0.744689        73.598545
# High                           21.020000  0.792992        76.040813
# Low                            28.300000  0.645355        66.674300
# Very High                      13.744444  0.894000        81.247231
# Very Low                       45.807692  0.515766        62.593769
#
#            expected_years_of_schooling  mean_years_of_schooling           gni
# Happiness
# Average                      13.825152                 9.720067  12837.486703
# High                         14.686982                10.062238  23328.916453
# Low                          11.910837                 7.871646   9738.938951
# Very High                    16.174038                11.656328  49902.623628
# Very Low                     10.120420                 5.475201   3204.945753

# %% [markdown]
# A good part of the variables seems well correlated, some are anticorelated too, but the "population" and "Generosity" variables aren't very correlated to the other variables.
#
# However we see that those two variables don't have the same mean value in the group analysis for different happiness values. Thus, it may be interesting to keep them as they are the lone conveyor of the information they carry.

# %% [markdown]
# **##2. Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function**

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Create the preprocessing pipelines for both numeric and categorical data.

numeric_features = X_train.select_dtypes(exclude=['object'])
numeric_features=numeric_features.columns.tolist()

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy="mean")), # we replace the missing value by the mean instead of 0 to avoid a huge bias by saying for example that the population is of 0 when the value is missing
    ('scaler', StandardScaler())]) # You will need to describe why this is being done in the next cell

categorical_features = ['region', 'sub-region']

#Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer',  SimpleImputer(strategy='most_frequent')), #we replace the missing value by the most frequent value
    ('onehot', OneHotEncoder(handle_unknown= "ignore"  ))]) #we don't raise an error when we face an unknown category

# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(transformers=[('num', numeric_transformer, numeric_features),('cat', categorical_transformer, categorical_features)])

#Fit your preprocessor object
preprocess=preprocessor.fit(X_train)

# %%
# Write function to transform data with preprocessor
def preprocessor(data):
    data.drop(['Country or region', 'name'], axis=1)
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (69, 33)

# %% [markdown]
# **##3. Fit model on preprocessed data and save preprocessor function and model**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier(n_estimators=10, random_state=46) #add random_state for reproductbility 

model.fit(preprocessor(X_train), y_train) #Fit the model

#Score the model
y_pred = model.predict(preprocessor(X_test))
accuracy = accuracy_score(y_test, y_pred) #https://scikit-learn.org/stable/modules/model_evaluation.html#accuracy-score
print(f"Accuracy of the model: {accuracy:.2f}")

# Your cell should have a score between 0-1 as output
# Out:
# Accuracy of the model: 0.21

# %% [markdown]
# ## 4. Generate predictions from X_test data and compare it with true labels in Y_test.csv file

# %%
import numpy as np
from sklearn.metrics import classification_report
#-- Generate predicted values (Model 1)
prediction_labels = model.predict(preprocessor(X_test))

## Write code to show model performance by comparing prediction_labels with true labels
#Simple classification report
report = classification_report(y_test, prediction_labels)
print("Classification Report:\n", report)

#Distribution study
#Add labels
labels = y_test.columns
prediction_labels = pd.DataFrame(data=prediction_labels, columns=labels)

#Create a color set
colors = ["#FFFF00","#ADFF2F","#FFA500","#00FF00","#FF0000"]
#Represent the plot of the predicted values for each of the real values with different colors
for i,label in enumerate(labels): #itereaate over lables
    indices = y_test.index[y_test[label] == 1].tolist() #extract all the indices of the correct label
    total = y_test.loc[indices].sum().sum() #calculate the total number of values for this label
    #extract the predicted values for this sub-sample and see the proportion of each categories
    prediction_labels_sub = prediction_labels.loc[indices].sum()/total 
    #represent it's distribution
    plt.bar(prediction_labels_sub.index, prediction_labels_sub.values, edgecolor=colors[i], facecolor="none", label=label, linewidth=2, alpha = 0.5)
plt.legend()
plt.title("Graph of the distribution of the predicted categories for each real category")
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.00      0.00      0.00         5
#            2       0.00      0.00      0.00         4
#            3       0.50      1.00      0.67         2
#            4       0.67      0.50      0.57         4
#
#    micro avg       0.44      0.21      0.29        19
#    macro avg       0.23      0.30      0.25        19
# weighted avg       0.19      0.21      0.19        19
#  samples avg       0.21      0.21      0.21        19
# C:\Users\mathi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mathi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Some correct prediction for extremes, far fewer good results for average or close to average categories.

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# It may be usefull to make more change as the model still has a hard time with close to average classes, and there may be room to improve it. However to do so there is a need to automatically scan the results for a good range of parameters values.

# %%
# Submit a third model using GridSearchCV
import time
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
t0 = time.time()
param_grid = {
    "n_estimators": np.arange(20, 101, 10), #Num of trees, not too much as we don't have a lot of data
    "max_depth": np.arange(5, 21, 5), #Max depth to limit to prevent overfitting
    "min_samples_split": np.arange(2, 9, 2),#Min num of samples to split a node
    "min_samples_leaf": np.arange(1,9,2),#Min num of samples in leaves
}

gridmodel = GridSearchCV(
    estimator=RandomForestClassifier(random_state=46, class_weight = "balanced"), #we keep the same randomness seed for reproductibility
    param_grid=param_grid,
    cv=5, # 5-fold cross-validation as the default one
    scoring='accuracy',#we use the same scoring metric
    n_jobs=-1 #We use all processors
)

#use model methods to fit score and predict model:
gridmodel.fit(preprocessor(X_train), y_train)

#extract best score and parameter by calling objects "best_score_" and "best_params_"
print("best mean cross-validation score: {:.3f}".format(gridmodel.best_score_))
print("best parameters: {}".format(gridmodel.best_params_))
t1 = time.time()
print(f"{(t1-t0)/60:.2f} min of calculation")
# Out:
# best mean cross-validation score: 0.521
# best parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 70}
# 1.89 min of calculation

# %%
#Submit new Model :

#-- Generate predicted values
y_pred = gridmodel.best_estimator_.predict(preprocessor(X_test))

## Write code to show model performance by comparing prediction_labels with true labels
accuracy = accuracy_score(y_test, y_pred) #https://scikit-learn.org/stable/modules/model_evaluation.html#accuracy-score
print(f"Accuracy of the model: {accuracy:.2f}")

report = classification_report(y_test, y_pred)
print("Classification Report:\n", report)

#Add labels
labels = y_test.columns
prediction_labels = pd.DataFrame(data=y_pred, columns=labels)

#Histograms
#Create a color set
colors = ["#FFFF00","#ADFF2F","#FFA500","#00FF00","#FF0000"]
#Represent the plot of the predicted values for each of the real values with different colors
for i,label in enumerate(labels): #itereaate over lables
    indices = y_test.index[y_test[label] == 1].tolist() #extract all the indices of the correct label
    total = y_test.loc[indices].sum().sum() #calculate the total number of values for this label
    #extract the predicted values for this sub-sample and see the proportion of each categories
    prediction_labels_sub = prediction_labels.loc[indices].sum()/total 
    #represent it's distribution
    plt.bar(prediction_labels_sub.index, prediction_labels_sub.values, edgecolor=colors[i], facecolor="none", label=label, linewidth=2, alpha = 0.5)
plt.legend()
plt.title("Graph of the distribution of the predicted categories for each real category")
plt.show()
# Out:
# Accuracy of the model: 0.32
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.33      0.20      0.25         5
#            2       0.00      0.00      0.00         4
#            3       0.50      1.00      0.67         2
#            4       0.60      0.75      0.67         4
#
#    micro avg       0.50      0.32      0.39        19
#    macro avg       0.29      0.39      0.32        19
# weighted avg       0.27      0.32      0.28        19
#  samples avg       0.32      0.32      0.32        19
# C:\Users\mathi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mathi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# It didn't worked that well. Maybe we can't do much better with a Random Forst Classifier.

# %%
# Here are several classic ML architectures you can consider choosing from to experiment with next:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from tqdm import tqdm

#creating a dic of all the models
models = {
    "KNeighborsClassifier": KNeighborsClassifier(),
    "SVC": SVC(kernel = "linear", C=1),
    "BaggingClassifier": BaggingClassifier(base_estimator=SVC(), random_state=46),
    "GradientBoostingClassifier": GradientBoostingClassifier(random_state=46)
}

#creating a dic of all the parameters dic assiciated to the models
param_grids = {
    "KNeighborsClassifier": {"n_neighbors": np.arange(2,15,3)},
    "SVC": {'C': [0.01, 0.1, 1, 10],
        'kernel': ['linear', 'rbf'],
        'gamma': [0.001, 0.01, 0.1, 1]}, 
    "BaggingClassifier": {"n_estimators": np.arange(5,100,10)},
    "GradientBoostingClassifier": {"n_estimators": np.arange(20,150,10),
                                  "learning_rate": np.arange(0.05, 0.2, 0.05),
                                  "max_depth": np.arange(2,7,2)}
}

#Training the models with a grid method
gridmodels = {}
for name, model in tqdm(models.items()):
    gridmodel = GridSearchCV(
    estimator = models[name],
    param_grid = param_grids[name],
    cv=5, # 5-fold cross-validation as the default one
    scoring='accuracy',#we use the same scoring metric
    n_jobs=-1 #We use all processors
    )
    if name == "KNeighborsClassifier":
        gridmodel.fit(preprocessor(X_train), y_train)
    else : #we convert our One-hot encoding to a list of labels
        y_train_labels = np.argmax(y_train, axis=1)
        gridmodel.fit(preprocessor(X_train), y_train_labels)
    gridmodels[name] = gridmodel
# Out:
#  50%|██████████████████████████████████████████                                          | 2/4 [00:01<00:01,  1.63it/s]C:\Users\mathi\anaconda3\Lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [03:57<00:00, 59.47s/it]

# %%
#-- Generate predicted values
results = {}
for name, gridmodel in gridmodels.items():
    if name == "KNeighborsClassifier":
        y_pred = gridmodel.predict(preprocessor(X_test))
    else:
        y_pred = gridmodel.predict(preprocessor(X_test))
        y_pred = np.eye(5)[y_pred]
    ## Write code to show model performance by comparing prediction_labels with true labels
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    results[name] = {
        "Best_Params": gridmodel.best_params_,
        "Best_Score": gridmodel.best_score_,
        "Test_Accuracy": accuracy,
        "Class_Report": report
    }
    
for model_name, metrics in results.items():
    print(f"Model: {model_name}")
    print(f"  Best Parameters: {metrics['Best_Params']}")
    print(f"  Best Cross-validation Score: {metrics['Best_Score']:.3f}")
    print(f"  Test Set Accuracy: {metrics['Test_Accuracy']:.3f}")
    print(f"  Classification report:")
    print(metrics['Class_Report'])
print(y_test.columns)
# Out:
# Model: KNeighborsClassifier
#   Best Parameters: {'n_neighbors': 5}
#   Best Cross-validation Score: 0.623
#   Test Set Accuracy: 0.421
#   Classification report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.40      0.40      0.40         5
#            2       0.50      0.25      0.33         4
#            3       0.67      1.00      0.80         2
#            4       0.75      0.75      0.75         4
#
#    micro avg       0.53      0.42      0.47        19
#    macro avg       0.46      0.48      0.46        19
# weighted avg       0.44      0.42      0.42        19
#  samples avg       0.42      0.42      0.42        19
#
# Model: SVC
#   Best Parameters: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
#   Best Cross-validation Score: 0.711
#   Test Set Accuracy: 0.632
#   Classification report:
#               precision    recall  f1-score   support
#
#            0       0.33      0.25      0.29         4
#            1       0.60      0.60      0.60         5
#            2       1.00      0.50      0.67         4
#            3       0.67      1.00      0.80         2
#            4       0.67      1.00      0.80         4
#
#    micro avg       0.63      0.63      0.63        19
#    macro avg       0.65      0.67      0.63        19
# weighted avg       0.65      0.63      0.61        19
#  samples avg       0.63      0.63      0.63        19
#
# Model: BaggingClassifier
#   Best Parameters: {'n_estimators': 55}
#   Best Cross-validation Score: 0.696
#   Test Set Accuracy: 0.474
#   Classification report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.60      0.60      0.60         5
#            2       0.00      0.00      0.00         4
#            3       0.67      1.00      0.80         2
#            4       0.57      1.00      0.73         4
#
#    micro avg       0.47      0.47      0.47        19
#    macro avg       0.37      0.52      0.43        19
# weighted avg       0.35      0.47      0.40        19
#  samples avg       0.47      0.47      0.47        19
#
# Model: GradientBoostingClassifier
#   Best Parameters: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 30}
#   Best Cross-validation Score: 0.609
#   Test Set Accuracy: 0.579
#   Classification report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57         4
#            1       0.67      0.40      0.50         5
#            2       0.50      0.50      0.50         4
#            3       0.50      1.00      0.67         2
#            4       0.60      0.75      0.67         4
#
#    micro avg       0.58      0.58      0.58        19
#    macro avg       0.59      0.63      0.58        19
# weighted avg       0.60      0.58      0.57        19
#  samples avg       0.58      0.58      0.58        19
#
# Index(['Average', 'High', 'Low', 'Very High', 'Very Low'], dtype='object')
# C:\Users\mathi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# All the parameters used are printed on the result of the previous cell. To find them we used a grid approach testing different sets of parameters with GridSearchCV(). Overall, the results are better than with the RandomForestClassifier, rising to an accuracy of 0.63 for the SVC model with very good performances to recognise "Low" happiness, good results for the other classes to except the average class with only a precision of 0.33.

# %% [markdown]
# # 6. Basic Deep Learning

# %%
# Now experiment with deep learning models:
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

#count features in input data
feature_count= preprocessor(X_train).shape[1]
num_classes=5

## Define a Neural Network Model with 5 layers 128->64->64->32->(?)
keras_model = Sequential([
    Dense(128, input_shape=(feature_count,)),# Input layer
    Activation('relu'),
    Dense(64),# Hidden layer 1
    Activation('relu'),
    Dense(64),# Hidden layer 2
    Activation('relu'),
    Dense(32),# Hidden layer 3
    Activation('relu'),
    Dense(num_classes),# Output layer
    Activation('softmax'),
])

#Use Softmax activation in last layer. How many neurons should there be in the last layer?

keras_model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\mathi\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\mathi\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               4352
#
#  activation (Activation)     (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  activation_1 (Activation)   (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  activation_3 (Activation)   (None, 32)                0
#
#  dense_4 (Dense)             (None, 5)                 165
#
#  activation_4 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 19013 (74.27 KB)
# Trainable params: 19013 (74.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile model
keras_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
km = keras_model.fit(preprocessor(X_train), y_train, ## Note that keras models require a one-hot-encoded y_train object
               batch_size = 20,
               epochs = 300, validation_split=0.25)
# Out:
# WARNING:tensorflow:From C:\Users\mathi\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/300
# WARNING:tensorflow:From C:\Users\mathi\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\mathi\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3/3 [==============================] - 2s 237ms/step - loss: 1.5699 - accuracy: 0.2157 - val_loss: 1.5808 - val_accuracy: 0.3889
# Epoch 2/300
# 3/3 [==============================] - 0s 40ms/step - loss: 1.5552 - accuracy: 0.2353 - val_loss: 1.5733 - val_accuracy: 0.3889
# Epoch 3/300
# 3/3 [==============================] - 0s 39ms/step - loss: 1.5400 - accuracy: 0.2549 - val_loss: 1.5670 - val_accuracy: 0.4444
# Epoch 4/300
# 3/3 [==============================] - 0s 41ms/step - loss: 1.5277 - accuracy: 0.2745 - val_loss: 1.5618 - val_accuracy: 0.4444
# Epoch 5/300
# 3/3 [==============================] - 0s 37ms/step - loss: 1.5155 - accuracy: 0.3922 - val_loss: 1.5565 - val_accuracy: 0.4444
# Epoch 6/300
# 3/3 [==============================] - 0s 35ms/step - loss: 1.4999 - accuracy: 0.4902 - val_loss: 1.5518 - val_accuracy: 0.4444
# Epoch 7/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.4877 - accuracy: 0.5098 - val_loss: 1.5471 - val_accuracy: 0.4444
# Epoch 8/300
# 3/3 [==============================] - 0s 44ms/step - loss: 1.4763 - accuracy: 0.5098 - val_loss: 1.5418 - val_accuracy: 0.4444
# Epoch 9/300
# 3/3 [==============================] - 0s 34ms/step - loss: 1.4634 - accuracy: 0.5098 - val_loss: 1.5370 - val_accuracy: 0.5000
# Epoch 10/300
# 3/3 [==============================] - 0s 45ms/step - loss: 1.4515 - accuracy: 0.5098 - val_loss: 1.5325 - val_accuracy: 0.5000
# Epoch 11/300
# 3/3 [==============================] - 0s 47ms/step - loss: 1.4391 - accuracy: 0.5098 - val_loss: 1.5273 - val_accuracy: 0.4444
# Epoch 12/300
# 3/3 [==============================] - 0s 34ms/step - loss: 1.4273 - accuracy: 0.5098 - val_loss: 1.5221 - val_accuracy: 0.4444
# Epoch 13/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.4156 - accuracy: 0.5098 - val_loss: 1.5167 - val_accuracy: 0.4444
# Epoch 14/300
# 3/3 [==============================] - 0s 44ms/step - loss: 1.4028 - accuracy: 0.5098 - val_loss: 1.5107 - val_accuracy: 0.4444
# Epoch 15/300
# 3/3 [==============================] - 0s 32ms/step - loss: 1.3914 - accuracy: 0.5098 - val_loss: 1.5045 - val_accuracy: 0.4444
# Epoch 16/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.3789 - accuracy: 0.5098 - val_loss: 1.4985 - val_accuracy: 0.4444
# Epoch 17/300
# 3/3 [==============================] - 0s 36ms/step - loss: 1.3668 - accuracy: 0.5294 - val_loss: 1.4934 - val_accuracy: 0.3889
# Epoch 18/300
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3568 - accuracy: 0.5098 - val_loss: 1.4866 - val_accuracy: 0.3889
# Epoch 19/300
# 3/3 [==============================] - 0s 29ms/step - loss: 1.3439 - accuracy: 0.5294 - val_loss: 1.4809 - val_accuracy: 0.3889
# Epoch 20/300
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3331 - accuracy: 0.5490 - val_loss: 1.4752 - val_accuracy: 0.3889
# Epoch 21/300
# 3/3 [==============================] - 0s 27ms/step - loss: 1.3209 - accuracy: 0.5686 - val_loss: 1.4700 - val_accuracy: 0.3889
# Epoch 22/300
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3096 - accuracy: 0.5686 - val_loss: 1.4643 - val_accuracy: 0.3889
# Epoch 23/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.2959 - accuracy: 0.5882 - val_loss: 1.4593 - val_accuracy: 0.3889
# Epoch 24/300
# 3/3 [==============================] - 0s 38ms/step - loss: 1.2836 - accuracy: 0.5686 - val_loss: 1.4530 - val_accuracy: 0.3889
# Epoch 25/300
# 3/3 [==============================] - 0s 56ms/step - loss: 1.2720 - accuracy: 0.5490 - val_loss: 1.4465 - val_accuracy: 0.3889
# Epoch 26/300
# 3/3 [==============================] - 0s 37ms/step - loss: 1.2597 - accuracy: 0.5882 - val_loss: 1.4408 - val_accuracy: 0.3889
# Epoch 27/300
# 3/3 [==============================] - 0s 29ms/step - loss: 1.2485 - accuracy: 0.5882 - val_loss: 1.4341 - val_accuracy: 0.3889
# Epoch 28/300
# 3/3 [==============================] - 0s 31ms/step - loss: 1.2350 - accuracy: 0.6078 - val_loss: 1.4286 - val_accuracy: 0.3889
# Epoch 29/300
# 3/3 [==============================] - 0s 27ms/step - loss: 1.2224 - accuracy: 0.6078 - val_loss: 1.4221 - val_accuracy: 0.3889
# Epoch 30/300
# 3/3 [==============================] - 0s 45ms/step - loss: 1.2105 - accuracy: 0.6078 - val_loss: 1.4158 - val_accuracy: 0.3889
# Epoch 31/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.1977 - accuracy: 0.6078 - val_loss: 1.4090 - val_accuracy: 0.3889
# Epoch 32/300
# 3/3 [==============================] - 0s 32ms/step - loss: 1.1856 - accuracy: 0.6078 - val_loss: 1.4013 - val_accuracy: 0.3889
# Epoch 33/300
# 3/3 [==============================] - 0s 29ms/step - loss: 1.1727 - accuracy: 0.6078 - val_loss: 1.3947 - val_accuracy: 0.3889
# Epoch 34/300
# 3/3 [==============================] - 0s 32ms/step - loss: 1.1606 - accuracy: 0.6275 - val_loss: 1.3866 - val_accuracy: 0.3889
# Epoch 35/300
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1506 - accuracy: 0.6275 - val_loss: 1.3812 - val_accuracy: 0.3889
# Epoch 36/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.1383 - accuracy: 0.6275 - val_loss: 1.3750 - val_accuracy: 0.3889
# Epoch 37/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.1273 - accuracy: 0.6275 - val_loss: 1.3710 - val_accuracy: 0.3889
# Epoch 38/300
# 3/3 [==============================] - 0s 32ms/step - loss: 1.1149 - accuracy: 0.6275 - val_loss: 1.3635 - val_accuracy: 0.3889
# Epoch 39/300
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1028 - accuracy: 0.6275 - val_loss: 1.3567 - val_accuracy: 0.4444
# Epoch 40/300
# 3/3 [==============================] - 0s 41ms/step - loss: 1.0948 - accuracy: 0.6275 - val_loss: 1.3483 - val_accuracy: 0.4444
# Epoch 41/300
# 3/3 [==============================] - 0s 38ms/step - loss: 1.0814 - accuracy: 0.6275 - val_loss: 1.3413 - val_accuracy: 0.4444
# Epoch 42/300
# 3/3 [==============================] - 0s 40ms/step - loss: 1.0711 - accuracy: 0.6275 - val_loss: 1.3338 - val_accuracy: 0.4444
# Epoch 43/300
# 3/3 [==============================] - 0s 36ms/step - loss: 1.0601 - accuracy: 0.6275 - val_loss: 1.3282 - val_accuracy: 0.5000
# Epoch 44/300
# 3/3 [==============================] - 0s 30ms/step - loss: 1.0506 - accuracy: 0.6275 - val_loss: 1.3219 - val_accuracy: 0.5000
# Epoch 45/300
# 3/3 [==============================] - 0s 34ms/step - loss: 1.0404 - accuracy: 0.6275 - val_loss: 1.3147 - val_accuracy: 0.5000
# Epoch 46/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.0305 - accuracy: 0.6471 - val_loss: 1.3071 - val_accuracy: 0.5000
# Epoch 47/300
# 3/3 [==============================] - 0s 27ms/step - loss: 1.0208 - accuracy: 0.6471 - val_loss: 1.3017 - val_accuracy: 0.5000
# Epoch 48/300
# 3/3 [==============================] - 0s 41ms/step - loss: 1.0123 - accuracy: 0.6471 - val_loss: 1.2939 - val_accuracy: 0.5000
# Epoch 49/300
# 3/3 [==============================] - 0s 29ms/step - loss: 1.0031 - accuracy: 0.6471 - val_loss: 1.2899 - val_accuracy: 0.5000
# Epoch 50/300
# 3/3 [==============================] - 0s 28ms/step - loss: 0.9948 - accuracy: 0.6471 - val_loss: 1.2787 - val_accuracy: 0.5000
# Epoch 51/300
# 3/3 [==============================] - 0s 40ms/step - loss: 0.9851 - accuracy: 0.6471 - val_loss: 1.2731 - val_accuracy: 0.5000
# Epoch 52/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.9779 - accuracy: 0.6471 - val_loss: 1.2676 - val_accuracy: 0.5000
# Epoch 53/300
# 3/3 [==============================] - 0s 47ms/step - loss: 0.9699 - accuracy: 0.6471 - val_loss: 1.2582 - val_accuracy: 0.5000
# Epoch 54/300
# 3/3 [==============================] - 0s 39ms/step - loss: 0.9624 - accuracy: 0.6667 - val_loss: 1.2498 - val_accuracy: 0.5000
# Epoch 55/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.9528 - accuracy: 0.6667 - val_loss: 1.2444 - val_accuracy: 0.5000
# Epoch 56/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.9458 - accuracy: 0.6667 - val_loss: 1.2369 - val_accuracy: 0.5000
# Epoch 57/300
# 3/3 [==============================] - 0s 42ms/step - loss: 0.9375 - accuracy: 0.6667 - val_loss: 1.2305 - val_accuracy: 0.5000
# Epoch 58/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.9303 - accuracy: 0.6667 - val_loss: 1.2268 - val_accuracy: 0.5000
# Epoch 59/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.9233 - accuracy: 0.6667 - val_loss: 1.2251 - val_accuracy: 0.5000
# Epoch 60/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.9152 - accuracy: 0.6471 - val_loss: 1.2168 - val_accuracy: 0.5000
# Epoch 61/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.9076 - accuracy: 0.6667 - val_loss: 1.2129 - val_accuracy: 0.5000
# Epoch 62/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.9010 - accuracy: 0.6667 - val_loss: 1.2101 - val_accuracy: 0.5000
# Epoch 63/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.8941 - accuracy: 0.6667 - val_loss: 1.2073 - val_accuracy: 0.5000
# Epoch 64/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.8874 - accuracy: 0.6667 - val_loss: 1.2041 - val_accuracy: 0.5000
# Epoch 65/300
# 3/3 [==============================] - 0s 27ms/step - loss: 0.8811 - accuracy: 0.6667 - val_loss: 1.1976 - val_accuracy: 0.5000
# Epoch 66/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.8737 - accuracy: 0.6667 - val_loss: 1.1900 - val_accuracy: 0.5000
# Epoch 67/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.8666 - accuracy: 0.6667 - val_loss: 1.1890 - val_accuracy: 0.5000
# Epoch 68/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.8607 - accuracy: 0.6667 - val_loss: 1.1855 - val_accuracy: 0.5000
# Epoch 69/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.8525 - accuracy: 0.6667 - val_loss: 1.1789 - val_accuracy: 0.5000
# Epoch 70/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.8461 - accuracy: 0.6667 - val_loss: 1.1752 - val_accuracy: 0.5000
# Epoch 71/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.8404 - accuracy: 0.6667 - val_loss: 1.1760 - val_accuracy: 0.5000
# Epoch 72/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.8343 - accuracy: 0.6667 - val_loss: 1.1669 - val_accuracy: 0.5000
# Epoch 73/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.8274 - accuracy: 0.6667 - val_loss: 1.1627 - val_accuracy: 0.5000
# Epoch 74/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.8212 - accuracy: 0.6863 - val_loss: 1.1568 - val_accuracy: 0.5000
# Epoch 75/300
# 3/3 [==============================] - 0s 43ms/step - loss: 0.8139 - accuracy: 0.7059 - val_loss: 1.1546 - val_accuracy: 0.5000
# Epoch 76/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.8095 - accuracy: 0.7255 - val_loss: 1.1468 - val_accuracy: 0.5000
# Epoch 77/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.8023 - accuracy: 0.7255 - val_loss: 1.1447 - val_accuracy: 0.5000
# Epoch 78/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7966 - accuracy: 0.7255 - val_loss: 1.1415 - val_accuracy: 0.5000
# Epoch 79/300
# 3/3 [==============================] - 0s 39ms/step - loss: 0.7902 - accuracy: 0.7255 - val_loss: 1.1412 - val_accuracy: 0.5000
# Epoch 80/300
# 3/3 [==============================] - 0s 48ms/step - loss: 0.7836 - accuracy: 0.7255 - val_loss: 1.1368 - val_accuracy: 0.5000
# Epoch 81/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7779 - accuracy: 0.7255 - val_loss: 1.1357 - val_accuracy: 0.5000
# Epoch 82/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7726 - accuracy: 0.7255 - val_loss: 1.1333 - val_accuracy: 0.5000
# Epoch 83/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7664 - accuracy: 0.7255 - val_loss: 1.1313 - val_accuracy: 0.5000
# Epoch 84/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7600 - accuracy: 0.7255 - val_loss: 1.1241 - val_accuracy: 0.5000
# Epoch 85/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7558 - accuracy: 0.7255 - val_loss: 1.1184 - val_accuracy: 0.5000
# Epoch 86/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7490 - accuracy: 0.7255 - val_loss: 1.1175 - val_accuracy: 0.5000
# Epoch 87/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7427 - accuracy: 0.7255 - val_loss: 1.1150 - val_accuracy: 0.5000
# Epoch 88/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7373 - accuracy: 0.7255 - val_loss: 1.1146 - val_accuracy: 0.5000
# Epoch 89/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7323 - accuracy: 0.7255 - val_loss: 1.1076 - val_accuracy: 0.5000
# Epoch 90/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7270 - accuracy: 0.7451 - val_loss: 1.1063 - val_accuracy: 0.4444
# Epoch 91/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7198 - accuracy: 0.7451 - val_loss: 1.1032 - val_accuracy: 0.4444
# Epoch 92/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7155 - accuracy: 0.7451 - val_loss: 1.0966 - val_accuracy: 0.4444
# Epoch 93/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7109 - accuracy: 0.7451 - val_loss: 1.0930 - val_accuracy: 0.4444
# Epoch 94/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7039 - accuracy: 0.7451 - val_loss: 1.0912 - val_accuracy: 0.4444
# Epoch 95/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6989 - accuracy: 0.7647 - val_loss: 1.0846 - val_accuracy: 0.4444
# Epoch 96/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6929 - accuracy: 0.7451 - val_loss: 1.0828 - val_accuracy: 0.4444
# Epoch 97/300
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6876 - accuracy: 0.7451 - val_loss: 1.0814 - val_accuracy: 0.4444
# Epoch 98/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.6817 - accuracy: 0.7843 - val_loss: 1.0776 - val_accuracy: 0.4444
# Epoch 99/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6764 - accuracy: 0.8039 - val_loss: 1.0740 - val_accuracy: 0.4444
# Epoch 100/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6722 - accuracy: 0.8235 - val_loss: 1.0766 - val_accuracy: 0.4444
# Epoch 101/300
# 3/3 [==============================] - 0s 49ms/step - loss: 0.6660 - accuracy: 0.8039 - val_loss: 1.0748 - val_accuracy: 0.4444
# Epoch 102/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6624 - accuracy: 0.8235 - val_loss: 1.0785 - val_accuracy: 0.4444
# Epoch 103/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6561 - accuracy: 0.8235 - val_loss: 1.0719 - val_accuracy: 0.4444
# Epoch 104/300
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6509 - accuracy: 0.8235 - val_loss: 1.0718 - val_accuracy: 0.4444
# Epoch 105/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6466 - accuracy: 0.8235 - val_loss: 1.0722 - val_accuracy: 0.4444
# Epoch 106/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6411 - accuracy: 0.8235 - val_loss: 1.0661 - val_accuracy: 0.5000
# Epoch 107/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6377 - accuracy: 0.8235 - val_loss: 1.0674 - val_accuracy: 0.5000
# Epoch 108/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6307 - accuracy: 0.8235 - val_loss: 1.0594 - val_accuracy: 0.5000
# Epoch 109/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.6257 - accuracy: 0.8235 - val_loss: 1.0580 - val_accuracy: 0.5000
# Epoch 110/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.6208 - accuracy: 0.8431 - val_loss: 1.0548 - val_accuracy: 0.5000
# Epoch 111/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.6152 - accuracy: 0.8431 - val_loss: 1.0583 - val_accuracy: 0.5000
# Epoch 112/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.6120 - accuracy: 0.8235 - val_loss: 1.0587 - val_accuracy: 0.5000
# Epoch 113/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6050 - accuracy: 0.8431 - val_loss: 1.0547 - val_accuracy: 0.5000
# Epoch 114/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6008 - accuracy: 0.8431 - val_loss: 1.0517 - val_accuracy: 0.5000
# Epoch 115/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5946 - accuracy: 0.8431 - val_loss: 1.0510 - val_accuracy: 0.5000
# Epoch 116/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5912 - accuracy: 0.8824 - val_loss: 1.0504 - val_accuracy: 0.5000
# Epoch 117/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5850 - accuracy: 0.8627 - val_loss: 1.0474 - val_accuracy: 0.5000
# Epoch 118/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5800 - accuracy: 0.8627 - val_loss: 1.0452 - val_accuracy: 0.5000
# Epoch 119/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5750 - accuracy: 0.8824 - val_loss: 1.0438 - val_accuracy: 0.5000
# Epoch 120/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5705 - accuracy: 0.8824 - val_loss: 1.0449 - val_accuracy: 0.5000
# Epoch 121/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5668 - accuracy: 0.8824 - val_loss: 1.0415 - val_accuracy: 0.5556
# Epoch 122/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5609 - accuracy: 0.8824 - val_loss: 1.0401 - val_accuracy: 0.5000
# Epoch 123/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5567 - accuracy: 0.8824 - val_loss: 1.0363 - val_accuracy: 0.5556
# Epoch 124/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5512 - accuracy: 0.8824 - val_loss: 1.0296 - val_accuracy: 0.5556
# Epoch 125/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5465 - accuracy: 0.8824 - val_loss: 1.0295 - val_accuracy: 0.5556
# Epoch 126/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5433 - accuracy: 0.8824 - val_loss: 1.0279 - val_accuracy: 0.5556
# Epoch 127/300
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5365 - accuracy: 0.8824 - val_loss: 1.0213 - val_accuracy: 0.5556
# Epoch 128/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5323 - accuracy: 0.8824 - val_loss: 1.0167 - val_accuracy: 0.5556
# Epoch 129/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5264 - accuracy: 0.9020 - val_loss: 1.0214 - val_accuracy: 0.5556
# Epoch 130/300
# 3/3 [==============================] - 0s 38ms/step - loss: 0.5211 - accuracy: 0.8824 - val_loss: 1.0183 - val_accuracy: 0.5000
# Epoch 131/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5162 - accuracy: 0.8824 - val_loss: 1.0173 - val_accuracy: 0.5000
# Epoch 132/300
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5113 - accuracy: 0.9020 - val_loss: 1.0177 - val_accuracy: 0.5556
# Epoch 133/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5076 - accuracy: 0.8824 - val_loss: 1.0162 - val_accuracy: 0.5556
# Epoch 134/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5021 - accuracy: 0.9020 - val_loss: 1.0182 - val_accuracy: 0.5556
# Epoch 135/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.4981 - accuracy: 0.9020 - val_loss: 1.0163 - val_accuracy: 0.5556
# Epoch 136/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.4926 - accuracy: 0.9020 - val_loss: 1.0154 - val_accuracy: 0.5556
# Epoch 137/300
# 3/3 [==============================] - 0s 38ms/step - loss: 0.4888 - accuracy: 0.9020 - val_loss: 1.0141 - val_accuracy: 0.5556
# Epoch 138/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.4836 - accuracy: 0.9020 - val_loss: 1.0130 - val_accuracy: 0.5556
# Epoch 139/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.4780 - accuracy: 0.9020 - val_loss: 1.0157 - val_accuracy: 0.5556
# Epoch 140/300
# 3/3 [==============================] - 0s 47ms/step - loss: 0.4737 - accuracy: 0.9020 - val_loss: 1.0127 - val_accuracy: 0.5556
# Epoch 141/300
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4697 - accuracy: 0.9020 - val_loss: 1.0136 - val_accuracy: 0.5000
# Epoch 142/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.4641 - accuracy: 0.9020 - val_loss: 1.0172 - val_accuracy: 0.5000
# Epoch 143/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.4606 - accuracy: 0.9216 - val_loss: 1.0187 - val_accuracy: 0.5000
# Epoch 144/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.4549 - accuracy: 0.9216 - val_loss: 1.0135 - val_accuracy: 0.5000
# Epoch 145/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.4504 - accuracy: 0.9216 - val_loss: 1.0162 - val_accuracy: 0.5556
# Epoch 146/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.4457 - accuracy: 0.9216 - val_loss: 1.0140 - val_accuracy: 0.5556
# Epoch 147/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.4410 - accuracy: 0.9216 - val_loss: 1.0142 - val_accuracy: 0.5556
# Epoch 148/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.4389 - accuracy: 0.9216 - val_loss: 1.0138 - val_accuracy: 0.5000
# Epoch 149/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.4326 - accuracy: 0.9412 - val_loss: 1.0162 - val_accuracy: 0.5000
# Epoch 150/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.4280 - accuracy: 0.9412 - val_loss: 1.0172 - val_accuracy: 0.5000
# Epoch 151/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.4241 - accuracy: 0.9412 - val_loss: 1.0224 - val_accuracy: 0.5000
# Epoch 152/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.4193 - accuracy: 0.9412 - val_loss: 1.0175 - val_accuracy: 0.5000
# Epoch 153/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.4149 - accuracy: 0.9412 - val_loss: 1.0167 - val_accuracy: 0.5000
# Epoch 154/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.4111 - accuracy: 0.9412 - val_loss: 1.0210 - val_accuracy: 0.5000
# Epoch 155/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.4067 - accuracy: 0.9412 - val_loss: 1.0171 - val_accuracy: 0.5000
# Epoch 156/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.4022 - accuracy: 0.9412 - val_loss: 1.0176 - val_accuracy: 0.5000
# Epoch 157/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3982 - accuracy: 0.9412 - val_loss: 1.0185 - val_accuracy: 0.5000
# Epoch 158/300
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3932 - accuracy: 0.9412 - val_loss: 1.0106 - val_accuracy: 0.5556
# Epoch 159/300
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3884 - accuracy: 0.9412 - val_loss: 1.0121 - val_accuracy: 0.5556
# Epoch 160/300
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3840 - accuracy: 0.9412 - val_loss: 1.0180 - val_accuracy: 0.5000
# Epoch 161/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3811 - accuracy: 0.9412 - val_loss: 1.0259 - val_accuracy: 0.5000
# Epoch 162/300
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3766 - accuracy: 0.9608 - val_loss: 1.0263 - val_accuracy: 0.5000
# Epoch 163/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.3719 - accuracy: 0.9412 - val_loss: 1.0257 - val_accuracy: 0.5000
# Epoch 164/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.3697 - accuracy: 0.9608 - val_loss: 1.0288 - val_accuracy: 0.5556
# Epoch 165/300
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3643 - accuracy: 0.9608 - val_loss: 1.0283 - val_accuracy: 0.5556
# Epoch 166/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3596 - accuracy: 0.9608 - val_loss: 1.0214 - val_accuracy: 0.5556
# Epoch 167/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3549 - accuracy: 0.9608 - val_loss: 1.0195 - val_accuracy: 0.5556
# Epoch 168/300
# 3/3 [==============================] - 0s 49ms/step - loss: 0.3523 - accuracy: 0.9608 - val_loss: 1.0269 - val_accuracy: 0.5556
# Epoch 169/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.3470 - accuracy: 0.9608 - val_loss: 1.0265 - val_accuracy: 0.5556
# Epoch 170/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.3434 - accuracy: 0.9608 - val_loss: 1.0252 - val_accuracy: 0.5556
# Epoch 171/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3403 - accuracy: 0.9608 - val_loss: 1.0227 - val_accuracy: 0.5556
# Epoch 172/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3355 - accuracy: 0.9608 - val_loss: 1.0284 - val_accuracy: 0.5556
# Epoch 173/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3317 - accuracy: 0.9608 - val_loss: 1.0321 - val_accuracy: 0.5556
# Epoch 174/300
# 3/3 [==============================] - 0s 54ms/step - loss: 0.3289 - accuracy: 0.9608 - val_loss: 1.0417 - val_accuracy: 0.5000
# Epoch 175/300
# 3/3 [==============================] - 0s 49ms/step - loss: 0.3259 - accuracy: 0.9608 - val_loss: 1.0427 - val_accuracy: 0.5556
# Epoch 176/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.3220 - accuracy: 0.9804 - val_loss: 1.0417 - val_accuracy: 0.5000
# Epoch 177/300
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3179 - accuracy: 0.9804 - val_loss: 1.0429 - val_accuracy: 0.5000
# Epoch 178/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3133 - accuracy: 1.0000 - val_loss: 1.0388 - val_accuracy: 0.5556
# Epoch 179/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3098 - accuracy: 1.0000 - val_loss: 1.0409 - val_accuracy: 0.5556
# Epoch 180/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3073 - accuracy: 1.0000 - val_loss: 1.0411 - val_accuracy: 0.5556
# Epoch 181/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.3024 - accuracy: 0.9804 - val_loss: 1.0431 - val_accuracy: 0.5556
# Epoch 182/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.2993 - accuracy: 1.0000 - val_loss: 1.0503 - val_accuracy: 0.5556
# Epoch 183/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2958 - accuracy: 1.0000 - val_loss: 1.0434 - val_accuracy: 0.5556
# Epoch 184/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2914 - accuracy: 1.0000 - val_loss: 1.0420 - val_accuracy: 0.5556
# Epoch 185/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2881 - accuracy: 0.9804 - val_loss: 1.0493 - val_accuracy: 0.5556
# Epoch 186/300
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2853 - accuracy: 1.0000 - val_loss: 1.0480 - val_accuracy: 0.5556
# Epoch 187/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2807 - accuracy: 1.0000 - val_loss: 1.0502 - val_accuracy: 0.5556
# Epoch 188/300
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2769 - accuracy: 1.0000 - val_loss: 1.0521 - val_accuracy: 0.5556
# Epoch 189/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2738 - accuracy: 1.0000 - val_loss: 1.0536 - val_accuracy: 0.5556
# Epoch 190/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2696 - accuracy: 1.0000 - val_loss: 1.0534 - val_accuracy: 0.5556
# Epoch 191/300
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2671 - accuracy: 1.0000 - val_loss: 1.0519 - val_accuracy: 0.5556
# Epoch 192/300
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2641 - accuracy: 1.0000 - val_loss: 1.0487 - val_accuracy: 0.5556
# Epoch 193/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2609 - accuracy: 1.0000 - val_loss: 1.0483 - val_accuracy: 0.5556
# Epoch 194/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2576 - accuracy: 1.0000 - val_loss: 1.0485 - val_accuracy: 0.5556
# Epoch 195/300
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2539 - accuracy: 1.0000 - val_loss: 1.0541 - val_accuracy: 0.5556
# Epoch 196/300
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2506 - accuracy: 1.0000 - val_loss: 1.0561 - val_accuracy: 0.5556
# Epoch 197/300
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2479 - accuracy: 1.0000 - val_loss: 1.0635 - val_accuracy: 0.5556
# Epoch 198/300
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2442 - accuracy: 1.0000 - val_loss: 1.0653 - val_accuracy: 0.5556
# Epoch 199/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2409 - accuracy: 1.0000 - val_loss: 1.0587 - val_accuracy: 0.5556
# Epoch 200/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2393 - accuracy: 1.0000 - val_loss: 1.0591 - val_accuracy: 0.5556
# Epoch 201/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2356 - accuracy: 1.0000 - val_loss: 1.0511 - val_accuracy: 0.6111
# Epoch 202/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2317 - accuracy: 1.0000 - val_loss: 1.0537 - val_accuracy: 0.5556
# Epoch 203/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2294 - accuracy: 1.0000 - val_loss: 1.0610 - val_accuracy: 0.5556
# Epoch 204/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.2259 - accuracy: 1.0000 - val_loss: 1.0652 - val_accuracy: 0.5556
# Epoch 205/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2230 - accuracy: 1.0000 - val_loss: 1.0625 - val_accuracy: 0.5556
# Epoch 206/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2195 - accuracy: 1.0000 - val_loss: 1.0634 - val_accuracy: 0.5556
# Epoch 207/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2182 - accuracy: 1.0000 - val_loss: 1.0636 - val_accuracy: 0.6111
# Epoch 208/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.2146 - accuracy: 1.0000 - val_loss: 1.0706 - val_accuracy: 0.5556
# Epoch 209/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.2115 - accuracy: 1.0000 - val_loss: 1.0804 - val_accuracy: 0.5556
# Epoch 210/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2100 - accuracy: 1.0000 - val_loss: 1.0841 - val_accuracy: 0.5556
# Epoch 211/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2070 - accuracy: 1.0000 - val_loss: 1.0778 - val_accuracy: 0.5556
# Epoch 212/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2044 - accuracy: 1.0000 - val_loss: 1.0846 - val_accuracy: 0.5556
# Epoch 213/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.2012 - accuracy: 1.0000 - val_loss: 1.0822 - val_accuracy: 0.5556
# Epoch 214/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1990 - accuracy: 1.0000 - val_loss: 1.0883 - val_accuracy: 0.5556
# Epoch 215/300
# 3/3 [==============================] - 0s 48ms/step - loss: 0.1970 - accuracy: 1.0000 - val_loss: 1.0928 - val_accuracy: 0.5556
# Epoch 216/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1942 - accuracy: 1.0000 - val_loss: 1.0953 - val_accuracy: 0.5556
# Epoch 217/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1906 - accuracy: 1.0000 - val_loss: 1.0968 - val_accuracy: 0.6111
# Epoch 218/300
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1889 - accuracy: 1.0000 - val_loss: 1.0961 - val_accuracy: 0.5556
# Epoch 219/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1861 - accuracy: 1.0000 - val_loss: 1.1021 - val_accuracy: 0.5556
# Epoch 220/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1836 - accuracy: 1.0000 - val_loss: 1.1054 - val_accuracy: 0.5556
# Epoch 221/300
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1816 - accuracy: 1.0000 - val_loss: 1.0984 - val_accuracy: 0.6111
# Epoch 222/300
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1800 - accuracy: 1.0000 - val_loss: 1.1020 - val_accuracy: 0.6111
# Epoch 223/300
# 3/3 [==============================] - 0s 56ms/step - loss: 0.1771 - accuracy: 1.0000 - val_loss: 1.1072 - val_accuracy: 0.6111
# Epoch 224/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1746 - accuracy: 1.0000 - val_loss: 1.1032 - val_accuracy: 0.6111
# Epoch 225/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1714 - accuracy: 1.0000 - val_loss: 1.1057 - val_accuracy: 0.6111
# Epoch 226/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1701 - accuracy: 1.0000 - val_loss: 1.1041 - val_accuracy: 0.6111
# Epoch 227/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1671 - accuracy: 1.0000 - val_loss: 1.1062 - val_accuracy: 0.6111
# Epoch 228/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1655 - accuracy: 1.0000 - val_loss: 1.1098 - val_accuracy: 0.6111
# Epoch 229/300
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1631 - accuracy: 1.0000 - val_loss: 1.1144 - val_accuracy: 0.6111
# Epoch 230/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1620 - accuracy: 1.0000 - val_loss: 1.1079 - val_accuracy: 0.6111
# Epoch 231/300
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1584 - accuracy: 1.0000 - val_loss: 1.1122 - val_accuracy: 0.6111
# Epoch 232/300
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1569 - accuracy: 1.0000 - val_loss: 1.1111 - val_accuracy: 0.6111
# Epoch 233/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1543 - accuracy: 1.0000 - val_loss: 1.1175 - val_accuracy: 0.6111
# Epoch 234/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1530 - accuracy: 1.0000 - val_loss: 1.1243 - val_accuracy: 0.6111
# Epoch 235/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1498 - accuracy: 1.0000 - val_loss: 1.1244 - val_accuracy: 0.6111
# Epoch 236/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1493 - accuracy: 1.0000 - val_loss: 1.1207 - val_accuracy: 0.6111
# Epoch 237/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1466 - accuracy: 1.0000 - val_loss: 1.1324 - val_accuracy: 0.6111
# Epoch 238/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1457 - accuracy: 1.0000 - val_loss: 1.1271 - val_accuracy: 0.6111
# Epoch 239/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1441 - accuracy: 1.0000 - val_loss: 1.1240 - val_accuracy: 0.6111
# Epoch 240/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1414 - accuracy: 1.0000 - val_loss: 1.1353 - val_accuracy: 0.6111
# Epoch 241/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1390 - accuracy: 1.0000 - val_loss: 1.1324 - val_accuracy: 0.6111
# Epoch 242/300
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1379 - accuracy: 1.0000 - val_loss: 1.1378 - val_accuracy: 0.6111
# Epoch 243/300
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1359 - accuracy: 1.0000 - val_loss: 1.1374 - val_accuracy: 0.6111
# Epoch 244/300
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1341 - accuracy: 1.0000 - val_loss: 1.1386 - val_accuracy: 0.6111
# Epoch 245/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1325 - accuracy: 1.0000 - val_loss: 1.1433 - val_accuracy: 0.6111
# Epoch 246/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1305 - accuracy: 1.0000 - val_loss: 1.1486 - val_accuracy: 0.6111
# Epoch 247/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1285 - accuracy: 1.0000 - val_loss: 1.1465 - val_accuracy: 0.6111
# Epoch 248/300
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1267 - accuracy: 1.0000 - val_loss: 1.1447 - val_accuracy: 0.6111
# Epoch 249/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1260 - accuracy: 1.0000 - val_loss: 1.1443 - val_accuracy: 0.6111
# Epoch 250/300
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1238 - accuracy: 1.0000 - val_loss: 1.1467 - val_accuracy: 0.6111
# Epoch 251/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1223 - accuracy: 1.0000 - val_loss: 1.1549 - val_accuracy: 0.6111
# Epoch 252/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1211 - accuracy: 1.0000 - val_loss: 1.1511 - val_accuracy: 0.6111
# Epoch 253/300
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1192 - accuracy: 1.0000 - val_loss: 1.1635 - val_accuracy: 0.6111
# Epoch 254/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1176 - accuracy: 1.0000 - val_loss: 1.1615 - val_accuracy: 0.6111
# Epoch 255/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1162 - accuracy: 1.0000 - val_loss: 1.1668 - val_accuracy: 0.6111
# Epoch 256/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1146 - accuracy: 1.0000 - val_loss: 1.1726 - val_accuracy: 0.6111
# Epoch 257/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1135 - accuracy: 1.0000 - val_loss: 1.1808 - val_accuracy: 0.6111
# Epoch 258/300
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1130 - accuracy: 1.0000 - val_loss: 1.1796 - val_accuracy: 0.6111
# Epoch 259/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1109 - accuracy: 1.0000 - val_loss: 1.1776 - val_accuracy: 0.6111
# Epoch 260/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1099 - accuracy: 1.0000 - val_loss: 1.1798 - val_accuracy: 0.6111
# Epoch 261/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1089 - accuracy: 1.0000 - val_loss: 1.1866 - val_accuracy: 0.6111
# Epoch 262/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1067 - accuracy: 1.0000 - val_loss: 1.1859 - val_accuracy: 0.6111
# Epoch 263/300
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1060 - accuracy: 1.0000 - val_loss: 1.1808 - val_accuracy: 0.6111
# Epoch 264/300
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1044 - accuracy: 1.0000 - val_loss: 1.1863 - val_accuracy: 0.6111
# Epoch 265/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1035 - accuracy: 1.0000 - val_loss: 1.1852 - val_accuracy: 0.6111
# Epoch 266/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1019 - accuracy: 1.0000 - val_loss: 1.1937 - val_accuracy: 0.6111
# Epoch 267/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1008 - accuracy: 1.0000 - val_loss: 1.1909 - val_accuracy: 0.6111
# Epoch 268/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1002 - accuracy: 1.0000 - val_loss: 1.1923 - val_accuracy: 0.6111
# Epoch 269/300
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0982 - accuracy: 1.0000 - val_loss: 1.1925 - val_accuracy: 0.6111
# Epoch 270/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0972 - accuracy: 1.0000 - val_loss: 1.2000 - val_accuracy: 0.6111
# Epoch 271/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0959 - accuracy: 1.0000 - val_loss: 1.2032 - val_accuracy: 0.6111
# Epoch 272/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0948 - accuracy: 1.0000 - val_loss: 1.2096 - val_accuracy: 0.6111
# Epoch 273/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0940 - accuracy: 1.0000 - val_loss: 1.2099 - val_accuracy: 0.6111
# Epoch 274/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0925 - accuracy: 1.0000 - val_loss: 1.2141 - val_accuracy: 0.6111
# Epoch 275/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0914 - accuracy: 1.0000 - val_loss: 1.2136 - val_accuracy: 0.6111
# Epoch 276/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0901 - accuracy: 1.0000 - val_loss: 1.2178 - val_accuracy: 0.6111
# Epoch 277/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0893 - accuracy: 1.0000 - val_loss: 1.2219 - val_accuracy: 0.6111
# Epoch 278/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0887 - accuracy: 1.0000 - val_loss: 1.2272 - val_accuracy: 0.6111
# Epoch 279/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0876 - accuracy: 1.0000 - val_loss: 1.2276 - val_accuracy: 0.6111
# Epoch 280/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0862 - accuracy: 1.0000 - val_loss: 1.2296 - val_accuracy: 0.6111
# Epoch 281/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0856 - accuracy: 1.0000 - val_loss: 1.2287 - val_accuracy: 0.6111
# Epoch 282/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0846 - accuracy: 1.0000 - val_loss: 1.2285 - val_accuracy: 0.6111
# Epoch 283/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0836 - accuracy: 1.0000 - val_loss: 1.2281 - val_accuracy: 0.6111
# Epoch 284/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0828 - accuracy: 1.0000 - val_loss: 1.2299 - val_accuracy: 0.6111
# Epoch 285/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0819 - accuracy: 1.0000 - val_loss: 1.2352 - val_accuracy: 0.6111
# Epoch 286/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0808 - accuracy: 1.0000 - val_loss: 1.2349 - val_accuracy: 0.6111
# Epoch 287/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0799 - accuracy: 1.0000 - val_loss: 1.2385 - val_accuracy: 0.6111
# Epoch 288/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0790 - accuracy: 1.0000 - val_loss: 1.2443 - val_accuracy: 0.6111
# Epoch 289/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0786 - accuracy: 1.0000 - val_loss: 1.2469 - val_accuracy: 0.6111
# Epoch 290/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0772 - accuracy: 1.0000 - val_loss: 1.2516 - val_accuracy: 0.6111
# Epoch 291/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0766 - accuracy: 1.0000 - val_loss: 1.2478 - val_accuracy: 0.6111
# Epoch 292/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0756 - accuracy: 1.0000 - val_loss: 1.2504 - val_accuracy: 0.6111
# Epoch 293/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0750 - accuracy: 1.0000 - val_loss: 1.2516 - val_accuracy: 0.6111
# Epoch 294/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0743 - accuracy: 1.0000 - val_loss: 1.2560 - val_accuracy: 0.6111
# Epoch 295/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0733 - accuracy: 1.0000 - val_loss: 1.2626 - val_accuracy: 0.6111
# Epoch 296/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0723 - accuracy: 1.0000 - val_loss: 1.2625 - val_accuracy: 0.6111
# Epoch 297/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0715 - accuracy: 1.0000 - val_loss: 1.2678 - val_accuracy: 0.6111
# Epoch 298/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0712 - accuracy: 1.0000 - val_loss: 1.2688 - val_accuracy: 0.6111
# Epoch 299/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0701 - accuracy: 1.0000 - val_loss: 1.2723 - val_accuracy: 0.6111
# Epoch 300/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0697 - accuracy: 1.0000 - val_loss: 1.2732 - val_accuracy: 0.6111

# %% [markdown]
# In the middle layers we used the rectified linear unit ("relu") activation function. It return the input if it is positive, and 0 if the input is negative.
#
# Softmax is used in the last layer because we want to classify into 5 categories our countries based on the data we have on them. Having softmax used for the output layer do just that, by puting all the weight of a result on one of the output neurons, thus equivalent to a class. This is also why we have 5 neurons in the last layer.

# %% [markdown]
# The validation loss keeps increasing after 150 epochs, revealing a possible overfitting of or model. Thus, we should train less and keep the number of apoch arounf 150 to avoid overfitting.

# %% [markdown]
# categorical_crossentropy  measures the dissimilarity between the true distribution (the actual labels) and the predicted distribution (the model's outputs). It is  adapted to evalutate a classifier like ours using a softmax activation function with one-hot encoded output, so we would keep it.
#
# The "sdg" or Stochastic gradient Descent optimizer is known in Numerical Methods to be a simple way to efficiently converge and get reduce the loss. Other more advanced optimizer exist but they are not needed in our simple case.

# %% [markdown]
# **Model training history**

# %%
## Your code to plot training and validation curves in a single plot (Make changes in the model cell to be able to do this)
plt.figure()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(km.history['loss'])
plt.plot(km.history['val_loss'])
plt.legend(['Training', 'Validation'])

plt.figure()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(km.history['accuracy'])
plt.plot(km.history['val_accuracy'])
plt.legend(['Training', 'Validation'], loc='lower right')

# %%
#-- Generate predicted y values
y_pred_prob = keras_model.predict(preprocessor(X_test))

#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index= np.argmax(y_pred_prob, axis=1) # Predict

# extract correct prediction labels
prediction_labels = [y_test.columns[i] for i in prediction_column_index]

## Write code to show model performance by comparing prediction_labels with true labels
y_test_labels = y_test.idxmax(axis=1)
accuracy = accuracy_score(y_test_labels, prediction_labels)
print(f"Accuracy of the Keras model: {accuracy:.4f}")

report = classification_report(y_test_labels, prediction_labels)
print("Classification Report:\n", report)
# Out:
# 1/1 [==============================] - 0s 288ms/step
# Accuracy of the Keras model: 0.4737
# Classification Report:
#                precision    recall  f1-score   support
#
#      Average       0.00      0.00      0.00         4
#         High       0.50      0.40      0.44         5
#          Low       0.50      0.50      0.50         4
#    Very High       0.50      1.00      0.67         2
#     Very Low       0.60      0.75      0.67         4
#
#     accuracy                           0.47        19
#    macro avg       0.42      0.53      0.46        19
# weighted avg       0.42      0.47      0.43        19

# %% [markdown]
# The results are correct in view of the previous models, though particularly bad for the "Average" class.

# %% [markdown]
# We have tried many different architectures and number of epochs, and none of those improve the model. Adding more layers doesn't change much of the result, removing one drops the accuracy. Reducing the number of epochs reduces the accuracy on the test set too, despite signs of overfitting, and increasing it definitely overfit the model. Overall, we didn't find ways to compensate for the very bad results of the "Average" class, introducing weights based on the frequency of categories in the training dataset would be a good way to solve this issue.>

# %% [markdown]
# ### Interpretation of the results

# %%
import shap

explainer = shap.DeepExplainer(keras_model, preprocessor(X_train))

# compute SHAP values for the test set
shap_values = explainer.shap_values(preprocessor(X_test))
# Out:
# C:\Users\mathi\anaconda3\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\mathi\anaconda3\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(

# %%
# Average the absolute SHAP values across all instances for each feature
shap_values_combined = np.abs(shap_values[0])  # Use shap_values[0] for the first class (0 for binary classification)
mean_shap_values = np.mean(shap_values_combined, axis=1)  # Change axis=0 to axis=1

print(mean_shap_values.shape)  # This should now show the correct shape
# Out:
# (33,)

# %%
columns = preprocess.get_feature_names_out()

# Create a DataFrame for easier plotting
shap_df = pd.DataFrame({
    'Feature': columns,
    'Mean SHAP Value': mean_shap_values
})

# Sort the DataFrame by Mean SHAP Value
shap_df = shap_df.sort_values(by='Mean SHAP Value', ascending=True)

# Plot the final bar plot
plt.figure(figsize=(12, 12))
plt.barh(shap_df['Feature'], shap_df['Mean SHAP Value'], color='skyblue')
plt.xlabel('Mean SHAP Value')
plt.title('Mean SHAP Values for All Features')
plt.show()

# %% [markdown]
# Shap allows for some interpretability of the resuts. We can see which entry parameters are the most influent but doesn't give a lot more. It can be seen as insuficient, for instance we don't see how the different parameters interacts, and what could be a key combination of features.
