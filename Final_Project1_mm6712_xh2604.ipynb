# %% [markdown]
# # Your Uni : xh2604 and mm6712
# # Your Full name : Xiyun Hu and Mathis Mallet
# # Link to your Public Github repository with Final report  : https://github.com/MathisMallet/Advanced-Machine-Learning

# %% [markdown]
# # World Happiness Classification Competition
# Goals :
# - Understand how the models function
# - Understand what the parameters control
# - Learn from the model experimentation process
# - Make a good looking notebook report
# - Upload as a personal project on Github
#
# **Overall Steps:**
# 1. Get data in and set up X_train / X_test / y_train
# 2. Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit predictions

# %% [markdown]
# ## 0. Get data in and set up X_train, X_test, y_train objects

# %% [markdown]
# **Instructions:**
# Upload the world_happiness_competition_data.zip and newcountryvars.csv files on Colab by pressing the Folder icon on left tab (Shows "Files" on hovering), and then clicking the left-most file upload button (Shows "Upload to Session Storage" Alt text on hovering)

# %% [markdown]
# ### Warning: run only once

# %%
# Get training data from course folder and unzip
# importing the zipfile module
from zipfile import ZipFile
import os


# loading the temp.zip and creating a zip object
with ZipFile("world_happiness_competition_data.zip", 'r') as zObject:

    # Extracting all the members of the zip
    # into a specific location.
    zObject.extractall()

# %%
# Load data
import pandas as pd
X_train = pd.read_csv('world_happiness_competition_data\\X_train.csv') # Load train features to train on
X_test =  pd.read_csv("world_happiness_competition_data\\X_test.csv") # Load test features to predict on
y_train =  pd.read_csv("world_happiness_competition_data\\y_train.csv") # Load y train (true labels)
y_test =  pd.read_csv("world_happiness_competition_data\\y_test.csv") # Load y test (true labels)
y_train_labels = y_train.idxmax(axis=1) # Examine what this does and write in next cell
y_test_labels = y_test.idxmax(axis=1) # Complete in a similar manner as above

X_train.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0            Latvia           1.187           1.465                    0.812
# 1           Burundi           0.046           0.447                    0.380
# 2           Belarus           1.067           1.465                    0.789
# 3           Liberia           0.073           0.922                    0.443
# 4           Ecuador           0.912           1.312                    0.868
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.264       0.075                      0.064
# 1                         0.220       0.176                      0.180
# 2                         0.235       0.094                      0.142
# 3                         0.370       0.233                      0.033
# 4                         0.498       0.126                      0.087
#
#       name    region                       sub-region  Terrorist_attacks
# 0   Latvia    Europe                  Northern Europe         125.611111
# 1  Burundi    Africa               Sub-Saharan Africa         155.000000
# 2  Belarus    Europe                   Eastern Europe           4.000000
# 3  Liberia    Africa               Sub-Saharan Africa        1419.095238
# 4  Ecuador  Americas  Latin America and the Caribbean           5.000000

# %% [markdown]
# **Write in the next cell what the y_train_labels = y_train.idxmax(axis=1) line does. What is the difference between y_train_labels and y_train?**

# %% [markdown]
# The initial DataFrame contains samples in rows and labels in columns. Each row is given a label by having the value 1 for one column, and 0 for all the others.The DataFrame attribute .idxmax(axis) return a list of the lengh of the Dataframe rows containing their corresponding labels (str). It does that by returning a list where each element is the name of the column for which the value is maximal (i.e 1 in our case), thus being the sample's label.

# %% [markdown]
# ##  Add new data

# %%
# Truncated and cleaned up region data to merge
countrydata=pd.read_csv("newcountryvars.csv")

countrydata.head()
# Out:
#   country_name  population  population_below_poverty_line       hdi  \
# 0        India  1339180127                           21.9  0.623559
# 1      Nigeria   190886311                           70.0  0.527105
# 2       Mexico   129163276                           46.2  0.761683
# 3     Pakistan   197015955                           29.5  0.550354
# 4   Bangladesh   164669751                           31.5  0.578824
#
#    life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0           68.322                    11.696590                 6.298834
# 1           53.057                     9.970482                 6.000000
# 2           76.972                    13.299090                 8.554985
# 3           66.365                     8.106910                 5.089460
# 4           71.985                    10.178706                 5.241577
#
#             gni
# 0   5663.474799
# 1   5442.901264
# 2  16383.106680
# 3   5031.173074
# 4   3341.490722

# %%
# Merge in new data to X_train and X_test by taking "Country or region" from first table and "country_name" from 2nd table.

X_train = pd.merge(X_train, countrydata, left_on="Country or region", right_on="country_name", how='left') #We remove 6 countries without enough data
X_test = pd.merge(X_test, countrydata, left_on="Country or region", right_on="country_name", how='left')
X_train = X_train.drop(columns =["country_name"])
X_test = X_test.drop(columns =["country_name"])

# %%
X_train.head(1)
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0            Latvia           1.187           1.465                    0.812
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.264       0.075                      0.064
#
#      name  region       sub-region  Terrorist_attacks  population  \
# 0  Latvia  Europe  Northern Europe         125.611111   1949670.0
#
#    population_below_poverty_line       hdi  life_expectancy  \
# 0                           25.5  0.829862           74.342
#
#    expected_years_of_schooling  mean_years_of_schooling          gni
# 0                     15.97411                11.736418  22589.17355

# %% [markdown]
# # EDA

# %%
print(X_train.dtypes)
# Out:
# Country or region                 object
# GDP per capita                   float64
# Social support                   float64
# Healthy life expectancy          float64
# Freedom to make life choices     float64
# Generosity                       float64
# Perceptions of corruption        float64
# name                              object
# region                            object
# sub-region                        object
# Terrorist_attacks                float64
# population                       float64
# population_below_poverty_line    float64
# hdi                              float64
# life_expectancy                  float64
# expected_years_of_schooling      float64
# mean_years_of_schooling          float64
# gni                              float64
# dtype: object

# %% [markdown]
# **Describe what you see above?**

# %% [markdown]
# X_train.dtypes reveals the type of data stored in each column of the DataFrame X_train. For instance "GDP per capita" data are floats, while "country_name" are objects.

# %% [markdown]
# **Find out the number and percentage of missing values in the table per column**

# %%
print("Training data missing values (%)")
print(X_train.isnull().sum()/(len(X_train))*100, "\n")
print("Testing data missing values (%)")
print(X_test.isnull().sum()/(len(X_test))*100)
# Out:
# Training data missing values (%)
# Country or region                 0.000000
# GDP per capita                    0.000000
# Social support                    0.000000
# Healthy life expectancy           0.000000
# Freedom to make life choices      0.000000
# Generosity                        0.000000
# Perceptions of corruption         0.000000
# name                              0.000000
# region                            0.000000
# sub-region                        0.000000
# Terrorist_attacks                 0.000000
# population                        8.695652
# population_below_poverty_line    15.942029
# hdi                               8.695652
# life_expectancy                   8.695652
# expected_years_of_schooling       8.695652
# mean_years_of_schooling           8.695652
# gni                               8.695652
# dtype: float64
#
# Testing data missing values (%)
# Country or region                 0.000000
# GDP per capita                    0.000000
# Social support                    0.000000
# Healthy life expectancy           0.000000
# Freedom to make life choices      0.000000
# Generosity                        0.000000
# Perceptions of corruption         0.000000
# name                              0.000000
# region                            0.000000
# sub-region                        0.000000
# Terrorist_attacks                 0.000000
# population                        0.000000
# population_below_poverty_line    21.052632
# hdi                               0.000000
# life_expectancy                   0.000000
# expected_years_of_schooling       0.000000
# mean_years_of_schooling           0.000000
# gni                               0.000000
# dtype: float64

# %% [markdown]
# **Plot the frequency distribution / histogram of some of the numerical features that you think are important**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# figure initialization
plt.figure(figsize=(12, 6))

# 'GDP per capita' histogram
plt.subplot(1, 3, 1)
sns.histplot(X_train["GDP per capita"], bins=10, kde=True, stat="percent")
plt.title("GDP per capita histogram")

# "Healthy life expectancy" histogram
plt.subplot(1, 3, 2)
sns.histplot(X_train["Healthy life expectancy"], bins=10, kde=True, stat="percent")
plt.title("Healthy life expectancy histogram")

# "Social support" histogram
plt.subplot(1, 3, 3)
sns.histplot(X_train['Social support'], bins=10, kde=True, stat="percent")
plt.title('Social support')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Plot the categorical variables and their distribution**

# %%
# figure initialization
plt.figure(figsize=(12, 6))

# "Social support" histogram
plt.subplot(1, 2, 1)
sns.countplot(x="region", data= X_train)
plt.title('region distribution')

# "sub-region" histogram
plt.subplot(1, 2, 2)
sns.countplot(x="sub-region", data= X_train)
plt.xticks(rotation=90)
plt.title('sub-region distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Explore relationships between variables (bivariate, etc), correlation tables, and how they associate with the target variable.**

# %%
#Correlation Matrix
X_train_num = X_train.select_dtypes(exclude=['object'])
correlation_matrix = X_train_num.corr()
#Ploting of the matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".1f", cmap='viridis', square=True)
plt.title('Correlation Matrix')
plt.show()

# Bivariate analysis
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.scatterplot(x="GDP per capita", y="Healthy life expectancy", data= X_train_num)
plt.title("Healthy life expectancy vs GDP per capita")
plt.subplot(1, 2, 2)
sns.scatterplot(x="Social support", y="population_below_poverty_line", data= X_train_num)
plt.title("population_below_poverty_line vs Social support")

plt.tight_layout()
plt.show()

#Grouped analysis
X_train_temp = X_train_num
X_train_temp["Happiness"] = y_train_labels
grouped_means = X_train_temp.groupby("Happiness").mean()
print(grouped_means)
# Out:
#            GDP per capita  Social support  Healthy life expectancy  \
# Happiness
# Average          0.978231        1.238769                 0.817000
# High             1.111353        1.394176                 0.851706
# Low              0.764333        1.092417                 0.599583
# Very High        1.400385        1.479923                 0.985077
# Very Low         0.393071        0.910571                 0.464857
#
#            Freedom to make life choices  Generosity  \
# Happiness
# Average                        0.305538    0.160231
# High                           0.409824    0.139941
# Low                            0.328083    0.144750
# Very High                      0.539000    0.250769
# Very Low                       0.248929    0.228357
#
#            Perceptions of corruption  Terrorist_attacks    population  \
# Happiness
# Average                     0.090615         278.484950  1.607969e+08
# High                        0.065412          57.545752  1.602114e+07
# Low                         0.073583          82.583333  2.822797e+07
# Very High                   0.245923          25.461538  1.333097e+07
# Very Low                    0.084214        1043.105442  3.050687e+07
#
#            population_below_poverty_line       hdi  life_expectancy  \
# Happiness
# Average                        17.718182  0.744689        73.598545
# High                           21.020000  0.792992        76.040813
# Low                            28.300000  0.645355        66.674300
# Very High                      13.744444  0.894000        81.247231
# Very Low                       45.807692  0.515766        62.593769
#
#            expected_years_of_schooling  mean_years_of_schooling           gni
# Happiness
# Average                      13.825152                 9.720067  12837.486703
# High                         14.686982                10.062238  23328.916453
# Low                          11.910837                 7.871646   9738.938951
# Very High                    16.174038                11.656328  49902.623628
# Very Low                     10.120420                 5.475201   3204.945753

# %% [markdown]
# **Write what you observed and your General comments on what should be done:**

# %% [markdown]
# A good part of the variables seems well correlated, some are anticorelated too, but the "population" and "Generosity" variables aren't very correlated to the other variables.
#
# However we see that those two variables don't have the same mean value in the group analysis for different happiness values. Thus, it may be interesting to keep them as they are the lone conveyor of the information they carry.

# %% [markdown]
# **##2. Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function**

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Create the preprocessing pipelines for both numeric and categorical data.

numeric_features = X_train.select_dtypes(exclude=['object'])
numeric_features=numeric_features.columns.tolist()

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy="mean")), # we replace the missing value by the mean instead of 0 to avoid a huge bias by saying for example that the population is of 0 when the value is missing
    ('scaler', StandardScaler())]) # You will need to describe why this is being done in the next cell

categorical_features = ['region', 'sub-region']

#Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer',  SimpleImputer(strategy='most_frequent')), #we replace the missing value by the most frequent value
    ('onehot', OneHotEncoder(handle_unknown= "ignore"  ))]) #we don't raise an error when we face an unknown category

# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(transformers=[('num', numeric_transformer, numeric_features),('cat', categorical_transformer, categorical_features)])

#Fit your preprocessor object
preprocess=preprocessor.fit(X_train)

# %% [markdown]
# **Describe step-by-step what we are doing above, and why? You are free to change how values are imputed. What change did you make if any, and why?**

# %% [markdown]
# In a first step we extract the names of the columns with numeric features in the variable "numeric features"
# Then we creat a transfomer that is meant to replace missing values by the mean value and then scale the data to be centered and normalized. We change the value of SimpleImputer's strategy to mean to limit the bias of missing values that would have been present if they were replaced by 0. The sclaing of the data is meant to improve the convergence of the neural network with comparable values between categories.
# The next step is to prepare the transformer of categorical values, with first a step that replace missing values by the most frequent categorical value (the "Modal value") and then encode the value in a normalised format that helps the neural network training. We also ignore new categories to avoid errors if a new one happen to exist.
#
# Eventually we finalize our transformers in a columnTransformer, associating columns of numerical values with the numerical transformer, and columns of categorical values with the categorical transformer.
#
# Then the last step is to fit the preprocessor (containing the transformers) with data X_train using the attribute .fit().

# %%
# Write function to transform data with preprocessor
def preprocessor(data):
    data.drop(['Country or region', 'name'], axis=1)
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %% [markdown]
# **What are the differences between the "preprocessor" object, the "preprocess" object, the "preprocessor" function,  and the "preprocessed_data" that is returned finally?**

# %% [markdown]
# The "preprocess" is the "preprocessor" fitted to the data X_train. The preprocessor function apply the preprocess to the dataframe inputed as an argument and return the preprocessed_dat, which is the data transformed by the preprocess.

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (69, 33)

# %% [markdown]
# **##3. Fit model on preprocessed data and save preprocessor function and model**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier(n_estimators=10, random_state=46) #add random_state for reproductbility 

model.fit(preprocessor(X_train), y_train) #Fit the model

#Score the model
y_pred = model.predict(preprocessor(X_test))
accuracy = accuracy_score(y_test, y_pred) #https://scikit-learn.org/stable/modules/model_evaluation.html#accuracy-score
print(f"Accuracy of the model: {accuracy:.2f}")

# Your cell should have a score between 0-1 as output
# Out:
# Accuracy of the model: 0.21

# %% [markdown]
# ## 4. Generate predictions from X_test data and compare it with true labels in Y_test.csv file

# %%
import numpy as np
from sklearn.metrics import classification_report
#-- Generate predicted values (Model 1)
prediction_labels = model.predict(preprocessor(X_test))

## Write code to show model performance by comparing prediction_labels with true labels
#Simple classification report
report = classification_report(y_test, prediction_labels)
print("Classification Report:\n", report)

#Distribution study
#Add labels
labels = y_test.columns
prediction_labels = pd.DataFrame(data=prediction_labels, columns=labels)

#Create a color set
colors = ["#FFFF00","#ADFF2F","#FFA500","#00FF00","#FF0000"]
#Represent the plot of the predicted values for each of the real values with different colors
for i,label in enumerate(labels): #itereaate over lables
    indices = y_test.index[y_test[label] == 1].tolist() #extract all the indices of the correct label
    total = y_test.loc[indices].sum().sum() #calculate the total number of values for this label
    #extract the predicted values for this sub-sample and see the proportion of each categories
    prediction_labels_sub = prediction_labels.loc[indices].sum()/total 
    #represent it's distribution
    plt.bar(prediction_labels_sub.index, prediction_labels_sub.values, edgecolor=colors[i], facecolor="none", label=label, linewidth=2, alpha = 0.5)
plt.legend()
plt.title("Graph of the distribution of the predicted categories for each real category")
plt.show()
# Out:
# C:\Users\mathi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mathi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.00      0.00      0.00         5
#            2       0.00      0.00      0.00         4
#            3       0.50      1.00      0.67         2
#            4       0.67      0.50      0.57         4
#
#    micro avg       0.44      0.21      0.29        19
#    macro avg       0.23      0.30      0.25        19
# weighted avg       0.19      0.21      0.19        19
#  samples avg       0.21      0.21      0.21        19

# %% [markdown]
# Some correct prediction for extremes, far fewer good results for average or close to average categories.

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
from sklearn.ensemble import RandomForestClassifier
for n in range(10,100, 10):
    model_2 = RandomForestClassifier(n_estimators=n, random_state=46, class_weight="balanced") #add random_state for reproductbility 

    model_2.fit(preprocessor(X_train), y_train) #Fit the model

    #Score the model
    y_pred = model_2.predict(preprocessor(X_test))
    accuracy = accuracy_score(y_test, y_pred) #https://scikit-learn.org/stable/modules/model_evaluation.html#accuracy-score
    print(f"Accuracy of the model: {accuracy:.2f} for n_estimator = {n}")
# Out:
# Accuracy of the model: 0.32 for n_estimator = 10
# Accuracy of the model: 0.37 for n_estimator = 20
# Accuracy of the model: 0.37 for n_estimator = 30
# Accuracy of the model: 0.32 for n_estimator = 40
# Accuracy of the model: 0.32 for n_estimator = 50
# Accuracy of the model: 0.32 for n_estimator = 60
# Accuracy of the model: 0.37 for n_estimator = 70
# Accuracy of the model: 0.32 for n_estimator = 80
# Accuracy of the model: 0.32 for n_estimator = 90

# %%
model_2 = RandomForestClassifier(n_estimators=30, random_state=46, class_weight="balanced") #add random_state for reproductbility 
model_2.fit(preprocessor(X_train), y_train) #Fit the model

#Score the model
y_pred = model_2.predict(preprocessor(X_test))
accuracy = accuracy_score(y_test, y_pred) #https://scikit-learn.org/stable/modules/model_evaluation.html#accuracy-score
print(f"Accuracy of the model: {accuracy:.2f}")
# Out:
# Accuracy of the model: 0.37

# %% [markdown]
# **What changes did you make, what do the parameters you changed control, and why does it improve performance?**

# %% [markdown]
# To improve the performance, we tested the model for a different number of estimators, and chose one of the best number in the tested range (1, 1000) with a step of 50 and (1,100) with a step of 10. We also tried it without fixing the randomness seed (random_state = 46) and chose to add a "balanced" weight to the classes to improve results on under-represented classes in the training dataset and overall result consistency. Eventually, chosing 30 tree gives good result as 10 proved insuficient, and a bigger number would give too many parameters for too few data.

# %%
#Evaluate Model 2:

#-- Generate predicted y values (Model 2)
prediction_labels = model_2.predict(preprocessor(X_test))


#Add labels
labels = y_test.columns
prediction_labels = pd.DataFrame(data=prediction_labels, columns=labels)

## Write code to show model performance by comparing prediction_labels with true labels
report = classification_report(y_test, y_pred)
print("Classification Report:\n", report)

#Create a color set
colors = ["#FFFF00","#ADFF2F","#FFA500","#00FF00","#FF0000"]
#Represent the plot of the predicted values for each of the real values with different colors
for i,label in enumerate(labels): #itereaate over lables
    indices = y_test.index[y_test[label] == 1].tolist() #extract all the indices of the correct label
    total = y_test.loc[indices].sum().sum() #calculate the total number of values for this label
    #extract the predicted values for this sub-sample and see the proportion of each categories
    prediction_labels_sub = prediction_labels.loc[indices].sum()/total 
    #represent it's distribution
    plt.bar(prediction_labels_sub.index, prediction_labels_sub.values, edgecolor=colors[i], facecolor="none", label=label, linewidth=2, alpha = 0.5)
plt.legend()
plt.title("Graph of the distribution of the predicted categories for each real category")
plt.show()
# Out:
# C:\Users\mathi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mathi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.67      0.40      0.50         5
#            2       0.00      0.00      0.00         4
#            3       0.50      1.00      0.67         2
#            4       0.75      0.75      0.75         4
#
#    micro avg       0.58      0.37      0.45        19
#    macro avg       0.38      0.43      0.38        19
# weighted avg       0.39      0.37      0.36        19
#  samples avg       0.37      0.37      0.37        19

# %% [markdown]
# **Do you think it is worth making more changes to the parameters? Should we keep trying random values and see what works better? What is an alternative to doing this manually?**

# %% [markdown]
# It may be usefull to make more change as the model still has a hard time with close to average classes, and there may be room to improve it. However to do so there is a need to automatically scan the results for a good range of parameters values.

# %%
# Submit a third model using GridSearchCV
import time
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
t0 = time.time()
param_grid = {
    "n_estimators": np.arange(20, 101, 10), #Num of trees, not too much as we don't have a lot of data
    "max_depth": np.arange(5, 21, 5), #Max depth to limit to prevent overfitting
    "min_samples_split": np.arange(2, 9, 2),#Min num of samples to split a node
    "min_samples_leaf": np.arange(1,9,2),#Min num of samples in leaves
}

gridmodel = GridSearchCV(
    estimator=RandomForestClassifier(random_state=46, class_weight = "balanced"), #we keep the same randomness seed for reproductibility
    param_grid=param_grid,
    cv=5, # 5-fold cross-validation as the default one
    scoring='accuracy',#we use the same scoring metric
    n_jobs=-1 #We use all processors
)

#use model methods to fit score and predict model:
gridmodel.fit(preprocessor(X_train), y_train)

#extract best score and parameter by calling objects "best_score_" and "best_params_"
print("best mean cross-validation score: {:.3f}".format(gridmodel.best_score_))
print("best parameters: {}".format(gridmodel.best_params_))
t1 = time.time()
print(f"{(t1-t0)/60:.2f} min of calculation")
# Out:
# best mean cross-validation score: 0.521
# best parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 70}
# 1.51 min of calculation

# %%
#Submit Model 3:

#-- Generate predicted values
y_pred = gridmodel.best_estimator_.predict(preprocessor(X_test))

## Write code to show model performance by comparing prediction_labels with true labels
accuracy = accuracy_score(y_test, y_pred) #https://scikit-learn.org/stable/modules/model_evaluation.html#accuracy-score
print(f"Accuracy of the model: {accuracy:.2f}")

report = classification_report(y_test, y_pred)
print("Classification Report:\n", report)

#Add labels
labels = y_test.columns
prediction_labels = pd.DataFrame(data=y_pred, columns=labels)

#Histograms
#Create a color set
colors = ["#FFFF00","#ADFF2F","#FFA500","#00FF00","#FF0000"]
#Represent the plot of the predicted values for each of the real values with different colors
for i,label in enumerate(labels): #itereaate over lables
    indices = y_test.index[y_test[label] == 1].tolist() #extract all the indices of the correct label
    total = y_test.loc[indices].sum().sum() #calculate the total number of values for this label
    #extract the predicted values for this sub-sample and see the proportion of each categories
    prediction_labels_sub = prediction_labels.loc[indices].sum()/total 
    #represent it's distribution
    plt.bar(prediction_labels_sub.index, prediction_labels_sub.values, edgecolor=colors[i], facecolor="none", label=label, linewidth=2, alpha = 0.5)
plt.legend()
plt.title("Graph of the distribution of the predicted categories for each real category")
plt.show()
# Out:
# Accuracy of the model: 0.32
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.33      0.20      0.25         5
#            2       0.00      0.00      0.00         4
#            3       0.50      1.00      0.67         2
#            4       0.60      0.75      0.67         4
#
#    micro avg       0.50      0.32      0.39        19
#    macro avg       0.29      0.39      0.32        19
# weighted avg       0.27      0.32      0.28        19
#  samples avg       0.32      0.32      0.32        19
# C:\Users\mathi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mathi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# It didn't worked very well. Maybe we can't do much better with a Random Forst Classifier.

# %%
# Here are several classic ML architectures you can consider choosing from to experiment with next:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from tqdm import tqdm

#creating a dic of all the models
models = {
    "KNeighborsClassifier": KNeighborsClassifier(),
    "SVC": SVC(kernel = "linear", C=1),
    "BaggingClassifier": BaggingClassifier(base_estimator=SVC(), random_state=46),
    "GradientBoostingClassifier": GradientBoostingClassifier(random_state=46)
}

#creating a dic of all the parameters dic assiciated to the models
param_grids = {
    "KNeighborsClassifier": {"n_neighbors": np.arange(2,15,3)},
    "SVC": {'C': [0.01, 0.1, 1, 10],
        'kernel': ['linear', 'rbf'],
        'gamma': [0.001, 0.01, 0.1, 1]}, 
    "BaggingClassifier": {"n_estimators": np.arange(5,100,10)},
    "GradientBoostingClassifier": {"n_estimators": np.arange(20,150,10),
                                  "learning_rate": np.arange(0.05, 0.2, 0.05),
                                  "max_depth": np.arange(2,7,2)}
}

#Training the models with a grid method
gridmodels = {}
for name, model in tqdm(models.items()):
    gridmodel = GridSearchCV(
    estimator = models[name],
    param_grid = param_grids[name],
    cv=5, # 5-fold cross-validation as the default one
    scoring='accuracy',#we use the same scoring metric
    n_jobs=-1 #We use all processors
    )
    if name == "KNeighborsClassifier":
        gridmodel.fit(preprocessor(X_train), y_train)
    else : #we convert our One-hot encoding to a list of labels
        y_train_labels = np.argmax(y_train, axis=1)
        gridmodel.fit(preprocessor(X_train), y_train_labels)
    gridmodels[name] = gridmodel
# Out:
#  50%|██████████████████████████████████████████                                          | 2/4 [00:00<00:00,  2.53it/s]C:\Users\mathi\anaconda3\Lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [02:58<00:00, 44.71s/it]

# %%
#-- Generate predicted values
results = {}
for name, gridmodel in gridmodels.items():
    if name == "KNeighborsClassifier":
        y_pred = gridmodel.predict(preprocessor(X_test))
    else:
        y_pred = gridmodel.predict(preprocessor(X_test))
        y_pred = np.eye(5)[y_pred]
    ## Write code to show model performance by comparing prediction_labels with true labels
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    results[name] = {
        "Best_Params": gridmodel.best_params_,
        "Best_Score": gridmodel.best_score_,
        "Test_Accuracy": accuracy,
        "Class_Report": report
    }
    
for model_name, metrics in results.items():
    print(f"Model: {model_name}")
    print(f"  Best Parameters: {metrics['Best_Params']}")
    print(f"  Best Cross-validation Score: {metrics['Best_Score']:.3f}")
    print(f"  Test Set Accuracy: {metrics['Test_Accuracy']:.3f}")
    print(f"  Classification report:")
    print(metrics['Class_Report'])
print(y_test.columns)
# Out:
# C:\Users\mathi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model: KNeighborsClassifier
#   Best Parameters: {'n_neighbors': 5}
#   Best Cross-validation Score: 0.623
#   Test Set Accuracy: 0.421
#   Classification report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.40      0.40      0.40         5
#            2       0.50      0.25      0.33         4
#            3       0.67      1.00      0.80         2
#            4       0.75      0.75      0.75         4
#
#    micro avg       0.53      0.42      0.47        19
#    macro avg       0.46      0.48      0.46        19
# weighted avg       0.44      0.42      0.42        19
#  samples avg       0.42      0.42      0.42        19
#
# Model: SVC
#   Best Parameters: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
#   Best Cross-validation Score: 0.711
#   Test Set Accuracy: 0.632
#   Classification report:
#               precision    recall  f1-score   support
#
#            0       0.33      0.25      0.29         4
#            1       0.60      0.60      0.60         5
#            2       1.00      0.50      0.67         4
#            3       0.67      1.00      0.80         2
#            4       0.67      1.00      0.80         4
#
#    micro avg       0.63      0.63      0.63        19
#    macro avg       0.65      0.67      0.63        19
# weighted avg       0.65      0.63      0.61        19
#  samples avg       0.63      0.63      0.63        19
#
# Model: BaggingClassifier
#   Best Parameters: {'n_estimators': 55}
#   Best Cross-validation Score: 0.696
#   Test Set Accuracy: 0.474
#   Classification report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.60      0.60      0.60         5
#            2       0.00      0.00      0.00         4
#            3       0.67      1.00      0.80         2
#            4       0.57      1.00      0.73         4
#
#    micro avg       0.47      0.47      0.47        19
#    macro avg       0.37      0.52      0.43        19
# weighted avg       0.35      0.47      0.40        19
#  samples avg       0.47      0.47      0.47        19
#
# Model: GradientBoostingClassifier
#   Best Parameters: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 30}
#   Best Cross-validation Score: 0.609
#   Test Set Accuracy: 0.579
#   Classification report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57         4
#            1       0.67      0.40      0.50         5
#            2       0.50      0.50      0.50         4
#            3       0.50      1.00      0.67         2
#            4       0.60      0.75      0.67         4
#
#    micro avg       0.58      0.58      0.58        19
#    macro avg       0.59      0.63      0.58        19
# weighted avg       0.60      0.58      0.57        19
#  samples avg       0.58      0.58      0.58        19
#
# Index(['Average', 'High', 'Low', 'Very High', 'Very Low'], dtype='object')

# %% [markdown]
# **Describe what were the parameters you defined in GradientBoostingClassifier, and/or BaggingClassifier, and/or KNNs, and/or SVC? What worked and why?**

# %% [markdown]
# All the parameters used are printed on the result of the previous cell. To find them we used a grid approach testing different sets of parameters with GridSearchCV(). Overall, the results are better than with the RandomForestClassifier, rising to an accuracy of 0.63 for the SVC model with very good performances to recognise "Low" happiness, good results for the other classes to except the average class with only a precision of 0.33.

# %% [markdown]
# # 6. Basic Deep Learning

# %%
# Now experiment with deep learning models:
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

#count features in input data
feature_count= preprocessor(X_train).shape[1]
num_classes=5

## Define a Neural Network Model with 5 layers 128->64->64->32->(?)
keras_model = Sequential([
    Dense(128, input_shape=(feature_count,)),# Input layer
    Activation('relu'),
    Dense(64),# Hidden layer 1
    Activation('relu'),
    Dense(64),# Hidden layer 2
    Activation('relu'),
    Dense(32),# Hidden layer 3
    Activation('relu'),
    Dense(num_classes),# Output layer
    Activation('softmax'),
])

#Use Softmax activation in last layer. How many neurons should there be in the last layer?

keras_model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_79 (Dense)            (None, 128)               4352
#
#  activation_79 (Activation)  (None, 128)               0
#
#  dense_80 (Dense)            (None, 64)                8256
#
#  activation_80 (Activation)  (None, 64)                0
#
#  dense_81 (Dense)            (None, 64)                4160
#
#  activation_81 (Activation)  (None, 64)                0
#
#  dense_82 (Dense)            (None, 32)                2080
#
#  activation_82 (Activation)  (None, 32)                0
#
#  dense_83 (Dense)            (None, 5)                 165
#
#  activation_83 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 19013 (74.27 KB)
# Trainable params: 19013 (74.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile model
keras_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
km = keras_model.fit(preprocessor(X_train), y_train, ## Note that keras models require a one-hot-encoded y_train object
               batch_size = 20,
               epochs = 300, validation_split=0.25)
# Out:
# Epoch 1/300
# 3/3 [==============================] - 1s 220ms/step - loss: 1.6170 - accuracy: 0.2157 - val_loss: 1.6232 - val_accuracy: 0.3333
# Epoch 2/300
# 3/3 [==============================] - 0s 31ms/step - loss: 1.5987 - accuracy: 0.2157 - val_loss: 1.6102 - val_accuracy: 0.3333
# Epoch 3/300
# 3/3 [==============================] - 0s 31ms/step - loss: 1.5822 - accuracy: 0.2157 - val_loss: 1.5980 - val_accuracy: 0.3333
# Epoch 4/300
# 3/3 [==============================] - 0s 35ms/step - loss: 1.5659 - accuracy: 0.2353 - val_loss: 1.5874 - val_accuracy: 0.3333
# Epoch 5/300
# 3/3 [==============================] - 0s 36ms/step - loss: 1.5503 - accuracy: 0.3333 - val_loss: 1.5760 - val_accuracy: 0.3889
# Epoch 6/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.5321 - accuracy: 0.3725 - val_loss: 1.5654 - val_accuracy: 0.3889
# Epoch 7/300
# 3/3 [==============================] - 0s 35ms/step - loss: 1.5163 - accuracy: 0.4118 - val_loss: 1.5547 - val_accuracy: 0.4444
# Epoch 8/300
# 3/3 [==============================] - 0s 40ms/step - loss: 1.4998 - accuracy: 0.4902 - val_loss: 1.5437 - val_accuracy: 0.5000
# Epoch 9/300
# 3/3 [==============================] - 0s 37ms/step - loss: 1.4835 - accuracy: 0.5098 - val_loss: 1.5337 - val_accuracy: 0.5000
# Epoch 10/300
# 3/3 [==============================] - 0s 35ms/step - loss: 1.4668 - accuracy: 0.5294 - val_loss: 1.5229 - val_accuracy: 0.6667
# Epoch 11/300
# 3/3 [==============================] - 0s 35ms/step - loss: 1.4507 - accuracy: 0.5294 - val_loss: 1.5129 - val_accuracy: 0.6111
# Epoch 12/300
# 3/3 [==============================] - 0s 32ms/step - loss: 1.4360 - accuracy: 0.5098 - val_loss: 1.5032 - val_accuracy: 0.6667
# Epoch 13/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.4221 - accuracy: 0.5294 - val_loss: 1.4934 - val_accuracy: 0.6667
# Epoch 14/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.
300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1412 - accuracy: 0.9804 - val_loss: 0.9527 - val_accuracy: 0.7222
# Epoch 258/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1403 - accuracy: 0.9804 - val_loss: 0.9521 - val_accuracy: 0.7222
# Epoch 259/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1386 - accuracy: 0.9804 - val_loss: 0.9574 - val_accuracy: 0.7222
# Epoch 260/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1374 - accuracy: 0.9804 - val_loss: 0.9589 - val_accuracy: 0.7222
# Epoch 261/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1363 - accuracy: 0.9804 - val_loss: 0.9569 - val_accuracy: 0.7222
# Epoch 262/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1348 - accuracy: 0.9804 - val_loss: 0.9508 - val_accuracy: 0.7222
# Epoch 263/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1330 - accuracy: 0.9804 - val_loss: 0.9563 - val_accuracy: 0.7222
# Epoch 264/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1317 - accuracy: 0.9804 - val_loss: 0.9641 - val_accuracy: 0.7222
# Epoch 265/300
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1308 - accuracy: 0.9804 - val_loss: 0.9652 - val_accuracy: 0.7222
# Epoch 266/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1293 - accuracy: 0.9804 - val_loss: 0.9691 - val_accuracy: 0.7222
# Epoch 267/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1290 - accuracy: 0.9804 - val_loss: 0.9760 - val_accuracy: 0.7222
# Epoch 268/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1272 - accuracy: 0.9804 - val_loss: 0.9830 - val_accuracy: 0.7222
# Epoch 269/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1257 - accuracy: 0.9804 - val_loss: 0.9775 - val_accuracy: 0.7222
# Epoch 270/300
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1243 - accuracy: 0.9804 - val_loss: 0.9804 - val_accuracy: 0.7222
# Epoch 271/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1235 - accuracy: 0.9804 - val_loss: 0.9783 - val_accuracy: 0.7222
# Epoch 272/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1217 - accuracy: 0.9804 - val_loss: 0.9797 - val_accuracy: 0.7222
# Epoch 273/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1205 - accuracy: 0.9804 - val_loss: 0.9837 - val_accuracy: 0.7222
# Epoch 274/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1203 - accuracy: 0.9804 - val_loss: 0.9846 - val_accuracy: 0.7222
# Epoch 275/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1185 - accuracy: 0.9804 - val_loss: 0.9838 - val_accuracy: 0.7222
# Epoch 276/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1179 - accuracy: 0.9804 - val_loss: 0.9784 - val_accuracy: 0.7222
# Epoch 277/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1161 - accuracy: 0.9804 - val_loss: 0.9805 - val_accuracy: 0.7222
# Epoch 278/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1154 - accuracy: 0.9804 - val_loss: 0.9905 - val_accuracy: 0.7222
# Epoch 279/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1139 - accuracy: 0.9804 - val_loss: 0.9941 - val_accuracy: 0.7222
# Epoch 280/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1128 - accuracy: 1.0000 - val_loss: 0.9903 - val_accuracy: 0.7222
# Epoch 281/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1119 - accuracy: 1.0000 - val_loss: 0.9879 - val_accuracy: 0.7222
# Epoch 282/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1107 - accuracy: 1.0000 - val_loss: 0.9974 - val_accuracy: 0.7222
# Epoch 283/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1100 - accuracy: 1.0000 - val_loss: 0.9945 - val_accuracy: 0.7222
# Epoch 284/300
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1088 - accuracy: 1.0000 - val_loss: 0.9908 - val_accuracy: 0.7222
# Epoch 285/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1079 - accuracy: 1.0000 - val_loss: 0.9918 - val_accuracy: 0.7222
# Epoch 286/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1068 - accuracy: 1.0000 - val_loss: 0.9971 - val_accuracy: 0.7222
# Epoch 287/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1055 - accuracy: 1.0000 - val_loss: 1.0051 - val_accuracy: 0.7222
# Epoch 288/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1046 - accuracy: 1.0000 - val_loss: 1.0047 - val_accuracy: 0.7222
# Epoch 289/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1034 - accuracy: 1.0000 - val_loss: 1.0090 - val_accuracy: 0.7222
# Epoch 290/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1025 - accuracy: 1.0000 - val_loss: 1.0112 - val_accuracy: 0.6667
# Epoch 291/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1019 - accuracy: 1.0000 - val_loss: 1.0135 - val_accuracy: 0.6667
# Epoch 292/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1009 - accuracy: 1.0000 - val_loss: 1.0073 - val_accuracy: 0.6667
# Epoch 293/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1002 - accuracy: 1.0000 - val_loss: 1.0084 - val_accuracy: 0.6667
# Epoch 294/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0985 - accuracy: 1.0000 - val_loss: 1.0098 - val_accuracy: 0.6667
# Epoch 295/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0977 - accuracy: 1.0000 - val_loss: 1.0119 - val_accuracy: 0.6667
# Epoch 296/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0966 - accuracy: 1.0000 - val_loss: 1.0094 - val_accuracy: 0.6667
# Epoch 297/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0958 - accuracy: 1.0000 - val_loss: 1.0150 - val_accuracy: 0.6667
# Epoch 298/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0947 - accuracy: 1.0000 - val_loss: 1.0134 - val_accuracy: 0.6667
# Epoch 299/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0938 - accuracy: 1.0000 - val_loss: 1.0169 - val_accuracy: 0.6667
# Epoch 300/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0933 - accuracy: 1.0000 - val_loss: 1.0207 - val_accuracy: 0.6667

# %% [markdown]
# **Which activations did you use in the middle layers? Why was softmax used in the last layer?**

# %% [markdown]
# In the middle layers we used the rectified linear unit ("relu") activation function. It return the input if it is positive, and 0 if the input is negative.
#
# Softmax is used in the last layer because we want to classify into 5 categories our countries based on the data we have on them. Having softmax used for the output layer do just that, by puting all the weight of a result on one of the output neurons, thus equivalent to a class. This is also why we have 5 neurons in the last layer.

# %% [markdown]
# **Was it a good idea to train for 300 epochs? Should you train a bit more? Why or why not?**

# %% [markdown]
# The validation loss keeps increasing after 150 epochs, revealing a possible overfitting of or model. Thus, we should train less and keep the number of apoch arounf 150 to avoid overfitting.

# %% [markdown]
# **Why is loss='categorical_crossentropy' and optimizer='sgd'? Would you want to change something? Why / Why not?**

# %% [markdown]
# categorical_crossentropy  measures the dissimilarity between the true distribution (the actual labels) and the predicted distribution (the model's outputs). It is  adapted to evalutate a classifier like ours using a softmax activation function with one-hot encoded output, so we would keep it.
#
# The "sdg" or Stochastic gradient Descent optimizer is known in Numerical Methods to be a simple way to efficiently converge and get reduce the loss. Other more advanced optimizer exist but they are not needed in our simple case.

# %% [markdown]
# **Can you try getting the model's training history out and plotting the curves?**

# %%
## Your code to plot training and validation curves in a single plot (Make changes in the model cell to be able to do this)
plt.figure()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(km.history['loss'])
plt.plot(km.history['val_loss'])
plt.legend(['Training', 'Validation'])

plt.figure()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(km.history['accuracy'])
plt.plot(km.history['val_accuracy'])
plt.legend(['Training', 'Validation'], loc='lower right')

# %%
#-- Generate predicted y values
y_pred_prob = keras_model.predict(preprocessor(X_test))

#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index= np.argmax(y_pred_prob, axis=1) # Predict

# extract correct prediction labels
prediction_labels = [y_test.columns[i] for i in prediction_column_index]

## Write code to show model performance by comparing prediction_labels with true labels
y_test_labels = y_test.idxmax(axis=1)
accuracy = accuracy_score(y_test_labels, prediction_labels)
print(f"Accuracy of the Keras model: {accuracy:.4f}")

report = classification_report(y_test_labels, prediction_labels)
print("Classification Report:\n", report)
# Out:
# 1/1 [==============================] - 0s 65ms/step
# Accuracy of the Keras model: 0.5789
# Classification Report:
#                precision    recall  f1-score   support
#
#      Average       0.00      0.00      0.00         4
#         High       0.60      0.60      0.60         5
#          Low       0.67      0.50      0.57         4
#    Very High       0.50      1.00      0.67         2
#     Very Low       0.67      1.00      0.80         4
#
#     accuracy                           0.58        19
#    macro avg       0.49      0.62      0.53        19
# weighted avg       0.49      0.58      0.52        19

# %% [markdown]
# The results are correct in view of the previous models, though particularly bad for the "Average" class.

# %%
## You are encouraged to try more experimentation and any other models by adding more code cells to this notebook:

## You can also try to import any new dataset pertaining to countries, merge it, and see if it helps the predictions.
## If it does not, try to explain why it wasn't helpful by exploring variable relationships.

# %% [markdown]
# ### Trying different set up

# %%
keras_model = Sequential([
    Dense(128, input_shape=(feature_count,)),# Input layer
    Activation('relu'),
    Dense(64),# Hidden layer 1
    Activation('relu'),
    Dense(64),# Hidden layer 2
    Activation('relu'),
    Dense(32),# Hidden layer 3
    Activation('relu'),
    Dense(num_classes),# Output layer
    Activation('softmax'),
])

# Compile model
keras_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
km = keras_model.fit(preprocessor(X_train), y_train, ## Note that keras models require a one-hot-encoded y_train object
               batch_size = 20,
               epochs = 400, validation_split=0.25)
# Out:
# Epoch 1/400
# 3/3 [==============================] - 1s 235ms/step - loss: 1.5922 - accuracy: 0.2353 - val_loss: 1.5433 - val_accuracy: 0.4444
# Epoch 2/400
# 3/3 [==============================] - 0s 36ms/step - loss: 1.5803 - accuracy: 0.2745 - val_loss: 1.5384 - val_accuracy: 0.3889
# Epoch 3/400
# 3/3 [==============================] - 0s 32ms/step - loss: 1.5672 - accuracy: 0.3333 - val_loss: 1.5335 - val_accuracy: 0.3889
# Epoch 4/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.5559 - accuracy: 0.3529 - val_loss: 1.5276 - val_accuracy: 0.4444
# Epoch 5/400
# 3/3 [==============================] - 0s 32ms/step - loss: 1.5453 - accuracy: 0.4118 - val_loss: 1.5241 - val_accuracy: 0.4444
# Epoch 6/400
# 3/3 [==============================] - 0s 32ms/step - loss: 1.5335 - accuracy: 0.4706 - val_loss: 1.5205 - val_accuracy: 0.5000
# Epoch 7/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.5239 - accuracy: 0.5098 - val_loss: 1.5156 - val_accuracy: 0.4444
# Epoch 8/400
# 3/3 [==============================] - 0s 32ms/step - loss: 1.5153 - accuracy: 0.5294 - val_loss: 1.5121 - val_accuracy: 0.5000
# Epoch 9/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.5054 - accuracy: 0.5882 - val_loss: 1.5085 - val_accuracy: 0.5000
# Epoch 10/400
# 3/3 [==============================] - 0s 32ms/step - loss: 1.4979 - accuracy: 0.5882 - val_loss: 1.5029 - val_accuracy: 0.5000
# Epoch 11/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.4881 - accuracy: 0.6078 - val_loss: 1.4990 - val_accuracy: 0.5000
# Epoch 12/400
# 3/3 [==============================] - 0s 32ms/step - loss: 1.4793 - accuracy: 0.5882 - val_loss: 1.4949 - val_accuracy: 0.5000
# Epoch 13/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.4706 - accuracy: 0.5882 - val_loss: 1.4899 - val_accuracy: 0.5000
# Epoch 14/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.
400
# 3/3 [==============================] - 0s 32ms/step - loss: 1.1862 - accuracy: 0.7059 - val_loss: 1.3251 - val_accuracy: 0.5556
# Epoch 44/400
# 3/3 [==============================] - 0s 30ms/step - loss: 1.1750 - accuracy: 0.7059 - val_loss: 1.3179 - val_accuracy: 0.5556
# Epoch 45/400
# 3/3 [==============================] - 0s 30ms/step - loss: 1.1646 - accuracy: 0.7059 - val_loss: 1.3145 - val_accuracy: 0.5556
# Epoch 46/400
# 3/3 [==============================] - 0s 32ms/step - loss: 1.1524 - accuracy: 0.7059 - val_loss: 1.3074 - val_accuracy: 0.5556
# Epoch 47/400
# 3/3 [==============================] - 0s 35ms/step - loss: 1.1417 - accuracy: 0.7059 - val_loss: 1.3029 - val_accuracy: 0.5556
# Epoch 48/400
# 3/3 [==============================] - 0s 32ms/step - loss: 1.1318 - accuracy: 0.7059 - val_loss: 1.2934 - val_accuracy: 0.6111
# Epoch 49/400
# 3/3 [==============================] - 0s 32ms/step - loss: 1.1196 - accuracy: 0.7059 - val_loss: 1.2844 - val_accuracy: 0.6111
# Epoch 50/400
# 3/3 [==============================] - 0s 32ms/step - loss: 1.1079 - accuracy: 0.7059 - val_loss: 1.2782 - val_accuracy: 0.6111
# Epoch 51/400
# 3/3 [==============================] - 0s 30ms/step - loss: 1.0973 - accuracy: 0.7059 - val_loss: 1.2718 - val_accuracy: 0.6111
# Epoch 52/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0872 - accuracy: 0.7059 - val_loss: 1.2639 - val_accuracy: 0.6111
# Epoch 53/400
# 3/3 [==============================] - 0s 30ms/step - loss: 1.0756 - accuracy: 0.7059 - val_loss: 1.2581 - val_accuracy: 0.6111
# Epoch 54/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0653 - accuracy: 0.7059 - val_loss: 1.2507 - val_accuracy: 0.6111
# Epoch 55/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0541 - accuracy: 0.7059 - val_loss: 1.2439 - val_accuracy: 0.6111
# Epoch 56/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0443 - accuracy: 0.7059 - val_loss: 1.2388 - val_accuracy: 0.6111
# Epoch 57/400
# 3/3 [==============================] - 0s 30ms/step - loss: 1.0335 - accuracy: 0.6863 - val_loss: 1.2349 - val_accuracy: 0.5556
# Epoch 58/400
# 3/3 [==============================] - 0s 30ms/step - loss: 1.0231 - accuracy: 0.7059 - val_loss: 1.2287 - val_accuracy: 0.6111
# Epoch 59/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0131 - accuracy: 0.6863 - val_loss: 1.2218 - val_accuracy: 0.6111
# Epoch 60/400
# 3/3 [==============================] - 0s 32ms/step - loss: 1.0060 - accuracy: 0.7059 - val_loss: 1.2180 - val_accuracy: 0.6111
# Epoch 61/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.9931 - accuracy: 0.7255 - val_loss: 1.2136 - val_accuracy: 0.6111
# Epoch 62/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.9835 - accuracy: 0.7059 - val_loss: 1.2068 - val_accuracy: 0.6111
# Epoch 63/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.9747 - accuracy: 0.7059 - val_loss: 1.1991 - val_accuracy: 0.6111
# Epoch 64/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.9668 - accuracy: 0.7059 - val_loss: 1.1908 - val_accuracy: 0.6111
# Epoch 65/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.9557 - accuracy: 0.7059 - val_loss: 1.1824 - val_accuracy: 0.6111
# Epoch 66/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.9463 - accuracy: 0.7059 - val_loss: 1.1795 - val_accuracy: 0.6111
# Epoch 67/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.9367 - accuracy: 0.7059 - val_loss: 1.1747 - val_accuracy: 0.6111
# Epoch 68/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.9275 - accuracy: 0.7255 - val_loss: 1.1702 - val_accuracy: 0.6111
# Epoch 69/400
# 3/3 [==============================] - 0s 42ms/step - loss: 0.9199 - accuracy: 0.7255 - val_loss: 1.1672 - val_accuracy: 0.6111
# Epoch 70/400
# 3/3 [==============================] - 0s 41ms/step - loss: 0.9087 - accuracy: 0.7255 - val_loss: 1.1615 - val_accuracy: 0.6111
# Epoch 71/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.9014 - accuracy: 0.7255 - val_loss: 1.1584 - val_accuracy: 0.6111
# Epoch 72/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.8923 - accuracy: 0.7255 - val_loss: 1.1501 - val_accuracy: 0.5556
# Epoch 73/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.8836 - accuracy: 0.7255 - val_loss: 1.1467 - val_accuracy: 0.6111
# Epoch 74/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.
400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2370 - accuracy: 0.9804 - val_loss: 1.0405 - val_accuracy: 0.5000
# Epoch 198/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2340 - accuracy: 0.9804 - val_loss: 1.0422 - val_accuracy: 0.5000
# Epoch 199/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2315 - accuracy: 0.9804 - val_loss: 1.0415 - val_accuracy: 0.5000
# Epoch 200/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.2290 - accuracy: 0.9804 - val_loss: 1.0443 - val_accuracy: 0.5000
# Epoch 201/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.2267 - accuracy: 0.9804 - val_loss: 1.0537 - val_accuracy: 0.5000
# Epoch 202/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2234 - accuracy: 0.9804 - val_loss: 1.0559 - val_accuracy: 0.5000
# Epoch 203/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2213 - accuracy: 0.9804 - val_loss: 1.0593 - val_accuracy: 0.5000
# Epoch 204/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2185 - accuracy: 0.9804 - val_loss: 1.0585 - val_accuracy: 0.5000
# Epoch 205/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2167 - accuracy: 0.9804 - val_loss: 1.0581 - val_accuracy: 0.5000
# Epoch 206/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2149 - accuracy: 0.9804 - val_loss: 1.0627 - val_accuracy: 0.5000
# Epoch 207/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2110 - accuracy: 0.9804 - val_loss: 1.0622 - val_accuracy: 0.5000
# Epoch 208/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.2087 - accuracy: 0.9804 - val_loss: 1.0646 - val_accuracy: 0.5000
# Epoch 209/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.2059 - accuracy: 0.9804 - val_loss: 1.0662 - val_accuracy: 0.5000
# Epoch 210/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.2046 - accuracy: 0.9804 - val_loss: 1.0699 - val_accuracy: 0.5000
# Epoch 211/400
# 3/3 [==============================] - 0s 51ms/step - loss: 0.2025 - accuracy: 1.0000 - val_loss: 1.0757 - val_accuracy: 0.5000
# Epoch 212/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1996 - accuracy: 0.9804 - val_loss: 1.0776 - val_accuracy: 0.5000
# Epoch 213/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1967 - accuracy: 0.9804 - val_loss: 1.0773 - val_accuracy: 0.5000
# Epoch 214/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1949 - accuracy: 0.9804 - val_loss: 1.0809 - val_accuracy: 0.5000
# Epoch 215/400
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1921 - accuracy: 1.0000 - val_loss: 1.0776 - val_accuracy: 0.5000
# Epoch 216/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1911 - accuracy: 1.0000 - val_loss: 1.0756 - val_accuracy: 0.5000
# Epoch 217/400
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1887 - accuracy: 0.9804 - val_loss: 1.0769 - val_accuracy: 0.5000
# Epoch 218/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1863 - accuracy: 0.9804 - val_loss: 1.0761 - val_accuracy: 0.5000
# Epoch 219/400
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1843 - accuracy: 0.9804 - val_loss: 1.0813 - val_accuracy: 0.5000
# Epoch 220/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1824 - accuracy: 0.9804 - val_loss: 1.0889 - val_accuracy: 0.5000
# Epoch 221/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1798 - accuracy: 1.0000 - val_loss: 1.0861 - val_accuracy: 0.5556
# Epoch 222/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1777 - accuracy: 1.0000 - val_loss: 1.0868 - val_accuracy: 0.5000
# Epoch 223/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1756 - accuracy: 1.0000 - val_loss: 1.0894 - val_accuracy: 0.5000
# Epoch 224/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1741 - accuracy: 1.0000 - val_loss: 1.0952 - val_accuracy: 0.5000
# Epoch 225/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1733 - accuracy: 1.0000 - val_loss: 1.0980 - val_accuracy: 0.5000
# Epoch 226/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1700 - accuracy: 1.0000 - val_loss: 1.1012 - val_accuracy: 0.5556
# Epoch 227/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1682 - accuracy: 1.0000 - val_loss: 1.1026 - val_accuracy: 0.5556
# Epoch 228/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1671 - accuracy: 1.0000 - val_loss: 1.1083 - val_accuracy: 0.5000
# Epoch 229/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1647 - accuracy: 1.0000 - val_loss: 1.1145 - val_accuracy: 0.5000
# Epoch 230/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1628 - accuracy: 1.0000 - val_loss: 1.1144 - val_accuracy: 0.5000
# Epoch 231/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1613 - accuracy: 1.0000 - val_loss: 1.1158 - val_accuracy: 0.5556
# Epoch 232/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1593 - accuracy: 1.0000 - val_loss: 1.1133 - val_accuracy: 0.5556
# Epoch 233/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1576 - accuracy: 1.0000 - val_loss: 1.1142 - val_accuracy: 0.5556
# Epoch 234/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1560 - accuracy: 1.0000 - val_loss: 1.1122 - val_accuracy: 0.5556
# Epoch 235/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1544 - accuracy: 1.0000 - val_loss: 1.1131 - val_accuracy: 0.5556
# Epoch 236/400
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1527 - accuracy: 1.0000 - val_loss: 1.1175 - val_accuracy: 0.5556
# Epoch 237/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1511 - accuracy: 1.0000 - val_loss: 1.1187 - val_accuracy: 0.5556
# Epoch 238/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1498 - accuracy: 1.0000 - val_loss: 1.1243 - val_accuracy: 0.5556
# Epoch 239/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1479 - accuracy: 1.0000 - val_loss: 1.1250 - val_accuracy: 0.5556
# Epoch 240/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1461 - accuracy: 1.0000 - val_loss: 1.1249 - val_accuracy: 0.5556
# Epoch 241/400
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1450 - accuracy: 1.0000 - val_loss: 1.1261 - val_accuracy: 0.5556
# Epoch 242/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1436 - accuracy: 1.0000 - val_loss: 1.1254 - val_accuracy: 0.5556
# Epoch 243/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1413 - accuracy: 1.0000 - val_loss: 1.1311 - val_accuracy: 0.5556
# Epoch 244/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1400 - accuracy: 1.0000 - val_loss: 1.1374 - val_accuracy: 0.5556
# Epoch 245/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1384 - accuracy: 1.0000 - val_loss: 1.1381 - val_accuracy: 0.5556
# Epoch 246/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1374 - accuracy: 1.0000 - val_loss: 1.1412 - val_accuracy: 0.5556
# Epoch 247/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1365 - accuracy: 1.0000 - val_loss: 1.1469 - val_accuracy: 0.5556
# Epoch 248/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1346 - accuracy: 1.0000 - val_loss: 1.1479 - val_accuracy: 0.5556
# Epoch 249/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1326 - accuracy: 1.0000 - val_loss: 1.1458 - val_accuracy: 0.5556
# Epoch 250/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1316 - accuracy: 1.0000 - val_loss: 1.1523 - val_accuracy: 0.5556
# Epoch 251/400
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1300 - accuracy: 1.0000 - val_loss: 1.1549 - val_accuracy: 0.5556
# Epoch 252/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1295 - accuracy: 1.0000 - val_loss: 1.1539 - val_accuracy: 0.5556
# Epoch 253/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1280 - accuracy: 1.0000 - val_loss: 1.1596 - val_accuracy: 0.5556
# Epoch 254/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1259 - accuracy: 1.0000 - val_loss: 1.1605 - val_accuracy: 0.5556
# Epoch 255/400
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1245 - accuracy: 1.0000 - val_loss: 1.1646 - val_accuracy: 0.5556
# Epoch 256/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1241 - accuracy: 1.0000 - val_loss: 1.1675 - val_accuracy: 0.5556
# Epoch 257/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1221 - accuracy: 1.0000 - val_loss: 1.1721 - val_accuracy: 0.5556
# Epoch 258/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1210 - accuracy: 1.0000 - val_loss: 1.1708 - val_accuracy: 0.5556
# Epoch 259/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1196 - accuracy: 1.0000 - val_loss: 1.1708 - val_accuracy: 0.5556
# Epoch 260/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1187 - accuracy: 1.0000 - val_loss: 1.1743 - val_accuracy: 0.5556
# Epoch 261/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1168 - accuracy: 1.0000 - val_loss: 1.1780 - val_accuracy: 0.5556
# Epoch 262/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1166 - accuracy: 1.0000 - val_loss: 1.1876 - val_accuracy: 0.5556
# Epoch 263/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1152 - accuracy: 1.0000 - val_loss: 1.1852 - val_accuracy: 0.5556
# Epoch 264/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1135 - accuracy: 1.0000 - val_loss: 1.1847 - val_accuracy: 0.5556
# Epoch 265/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1128 - accuracy: 1.0000 - val_loss: 1.1834 - val_accuracy: 0.5556
# Epoch 266/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1116 - accuracy: 1.0000 - val_loss: 1.1849 - val_accuracy: 0.5556
# Epoch 267/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1107 - accuracy: 1.0000 - val_loss: 1.1870 - val_accuracy: 0.5556
# Epoch 268/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1092 - accuracy: 1.0000 - val_loss: 1.1852 - val_accuracy: 0.5556
# Epoch 269/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1079 - accuracy: 1.0000 - val_loss: 1.1870 - val_accuracy: 0.5556
# Epoch 270/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1071 - accuracy: 1.0000 - val_loss: 1.1900 - val_accuracy: 0.5556
# Epoch 271/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1062 - accuracy: 1.0000 - val_loss: 1.1888 - val_accuracy: 0.5556
# Epoch 272/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1044 - accuracy: 1.0000 - val_loss: 1.1929 - val_accuracy: 0.5556
# Epoch 273/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1038 - accuracy: 1.0000 - val_loss: 1.1995 - val_accuracy: 0.5556
# Epoch 274/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1024 - accuracy: 1.0000 - val_loss: 1.2041 - val_accuracy: 0.5556
# Epoch 275/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1014 - accuracy: 1.0000 - val_loss: 1.2032 - val_accuracy: 0.5556
# Epoch 276/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1005 - accuracy: 1.0000 - val_loss: 1.2057 - val_accuracy: 0.5556
# Epoch 277/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0998 - accuracy: 1.0000 - val_loss: 1.2056 - val_accuracy: 0.5556
# Epoch 278/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0984 - accuracy: 1.0000 - val_loss: 1.2096 - val_accuracy: 0.5556
# Epoch 279/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0978 - accuracy: 1.0000 - val_loss: 1.2103 - val_accuracy: 0.5556
# Epoch 280/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0980 - accuracy: 1.0000 - val_loss: 1.2164 - val_accuracy: 0.5556
# Epoch 281/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0955 - accuracy: 1.0000 - val_loss: 1.2207 - val_accuracy: 0.5556
# Epoch 282/400
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0944 - accuracy: 1.0000 - val_loss: 1.2233 - val_accuracy: 0.5556
# Epoch 283/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0946 - accuracy: 1.0000 - val_loss: 1.2291 - val_accuracy: 0.5556
# Epoch 284/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0934 - accuracy: 1.0000 - val_loss: 1.2261 - val_accuracy: 0.5556
# Epoch 285/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0922 - accuracy: 1.0000 - val_loss: 1.2309 - val_accuracy: 0.5556
# Epoch 286/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0909 - accuracy: 1.0000 - val_loss: 1.2360 - val_accuracy: 0.5556
# Epoch 287/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0907 - accuracy: 1.0000 - val_loss: 1.2351 - val_accuracy: 0.5556
# Epoch 288/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0894 - accuracy: 1.0000 - val_loss: 1.2411 - val_accuracy: 0.5556
# Epoch 289/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0888 - accuracy: 1.0000 - val_loss: 1.2403 - val_accuracy: 0.5556
# Epoch 290/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0886 - accuracy: 1.0000 - val_loss: 1.2364 - val_accuracy: 0.5556
# Epoch 291/400
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0874 - accuracy: 1.0000 - val_loss: 1.2352 - val_accuracy: 0.5556
# Epoch 292/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0863 - accuracy: 1.0000 - val_loss: 1.2417 - val_accuracy: 0.5556
# Epoch 293/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0853 - accuracy: 1.0000 - val_loss: 1.2483 - val_accuracy: 0.5556
# Epoch 294/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0841 - accuracy: 1.0000 - val_loss: 1.2488 - val_accuracy: 0.5556
# Epoch 295/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0835 - accuracy: 1.0000 - val_loss: 1.2542 - val_accuracy: 0.5556
# Epoch 296/400
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0833 - accuracy: 1.0000 - val_loss: 1.2556 - val_accuracy: 0.5556
# Epoch 297/400
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0816 - accuracy: 1.0000 - val_loss: 1.2601 - val_accuracy: 0.5556
# Epoch 298/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0814 - accuracy: 1.0000 - val_loss: 1.2651 - val_accuracy: 0.5556
# Epoch 299/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0804 - accuracy: 1.0000 - val_loss: 1.2651 - val_accuracy: 0.5556
# Epoch 300/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0794 - accuracy: 1.0000 - val_loss: 1.2664 - val_accuracy: 0.5556
# Epoch 301/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0790 - accuracy: 1.0000 - val_loss: 1.2670 - val_accuracy: 0.5556
# Epoch 302/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0782 - accuracy: 1.0000 - val_loss: 1.2681 - val_accuracy: 0.5556
# Epoch 303/400
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0779 - accuracy: 1.0000 - val_loss: 1.2786 - val_accuracy: 0.5556
# Epoch 304/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0766 - accuracy: 1.0000 - val_loss: 1.2757 - val_accuracy: 0.5556
# Epoch 305/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0764 - accuracy: 1.0000 - val_loss: 1.2842 - val_accuracy: 0.5556
# Epoch 306/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0753 - accuracy: 1.0000 - val_loss: 1.2843 - val_accuracy: 0.5556
# Epoch 307/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0749 - accuracy: 1.0000 - val_loss: 1.2924 - val_accuracy: 0.5556
# Epoch 308/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0740 - accuracy: 1.0000 - val_loss: 1.2873 - val_accuracy: 0.5556
# Epoch 309/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0734 - accuracy: 1.0000 - val_loss: 1.2888 - val_accuracy: 0.5556
# Epoch 310/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0723 - accuracy: 1.0000 - val_loss: 1.2871 - val_accuracy: 0.5556
# Epoch 311/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0716 - accuracy: 1.0000 - val_loss: 1.2901 - val_accuracy: 0.5556
# Epoch 312/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0711 - accuracy: 1.0000 - val_loss: 1.2901 - val_accuracy: 0.5556
# Epoch 313/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0706 - accuracy: 1.0000 - val_loss: 1.2978 - val_accuracy: 0.5556
# Epoch 314/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0701 - accuracy: 1.0000 - val_loss: 1.3058 - val_accuracy: 0.5556
# Epoch 315/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0692 - accuracy: 1.0000 - val_loss: 1.3094 - val_accuracy: 0.5556
# Epoch 316/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0689 - accuracy: 1.0000 - val_loss: 1.3141 - val_accuracy: 0.5556
# Epoch 317/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0679 - accuracy: 1.0000 - val_loss: 1.3115 - val_accuracy: 0.5556
# Epoch 318/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0671 - accuracy: 1.0000 - val_loss: 1.3101 - val_accuracy: 0.5556
# Epoch 319/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0667 - accuracy: 1.0000 - val_loss: 1.3126 - val_accuracy: 0.5556
# Epoch 320/400
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0660 - accuracy: 1.0000 - val_loss: 1.3155 - val_accuracy: 0.5556
# Epoch 321/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0658 - accuracy: 1.0000 - val_loss: 1.3204 - val_accuracy: 0.5556
# Epoch 322/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0652 - accuracy: 1.0000 - val_loss: 1.3144 - val_accuracy: 0.5556
# Epoch 323/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0643 - accuracy: 1.0000 - val_loss: 1.3144 - val_accuracy: 0.5556
# Epoch 324/400
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0639 - accuracy: 1.0000 - val_loss: 1.3137 - val_accuracy: 0.5556
# Epoch 325/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0633 - accuracy: 1.0000 - val_loss: 1.3190 - val_accuracy: 0.5556
# Epoch 326/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0629 - accuracy: 1.0000 - val_loss: 1.3219 - val_accuracy: 0.5556
# Epoch 327/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0620 - accuracy: 1.0000 - val_loss: 1.3217 - val_accuracy: 0.5556
# Epoch 328/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0620 - accuracy: 1.0000 - val_loss: 1.3243 - val_accuracy: 0.5556
# Epoch 329/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0610 - accuracy: 1.0000 - val_loss: 1.3285 - val_accuracy: 0.5556
# Epoch 330/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0605 - accuracy: 1.0000 - val_loss: 1.3290 - val_accuracy: 0.5556
# Epoch 331/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0599 - accuracy: 1.0000 - val_loss: 1.3316 - val_accuracy: 0.5556
# Epoch 332/400
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0592 - accuracy: 1.0000 - val_loss: 1.3320 - val_accuracy: 0.5556
# Epoch 333/400
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0588 - accuracy: 1.0000 - val_loss: 1.3358 - val_accuracy: 0.5556
# Epoch 334/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0584 - accuracy: 1.0000 - val_loss: 1.3401 - val_accuracy: 0.5556
# Epoch 335/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0582 - accuracy: 1.0000 - val_loss: 1.3377 - val_accuracy: 0.5556
# Epoch 336/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0578 - accuracy: 1.0000 - val_loss: 1.3461 - val_accuracy: 0.5556
# Epoch 337/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0570 - accuracy: 1.0000 - val_loss: 1.3474 - val_accuracy: 0.5556
# Epoch 338/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0564 - accuracy: 1.0000 - val_loss: 1.3481 - val_accuracy: 0.5556
# Epoch 339/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0558 - accuracy: 1.0000 - val_loss: 1.3494 - val_accuracy: 0.5556
# Epoch 340/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0554 - accuracy: 1.0000 - val_loss: 1.3515 - val_accuracy: 0.5556
# Epoch 341/400
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0554 - accuracy: 1.0000 - val_loss: 1.3519 - val_accuracy: 0.5556
# Epoch 342/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0547 - accuracy: 1.0000 - val_loss: 1.3556 - val_accuracy: 0.5556
# Epoch 343/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0541 - accuracy: 1.0000 - val_loss: 1.3559 - val_accuracy: 0.5556
# Epoch 344/400
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0540 - accuracy: 1.0000 - val_loss: 1.3561 - val_accuracy: 0.5556
# Epoch 345/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0538 - accuracy: 1.0000 - val_loss: 1.3681 - val_accuracy: 0.5556
# Epoch 346/400
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0532 - accuracy: 1.0000 - val_loss: 1.3729 - val_accuracy: 0.5556
# Epoch 347/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0527 - accuracy: 1.0000 - val_loss: 1.3739 - val_accuracy: 0.5556
# Epoch 348/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0520 - accuracy: 1.0000 - val_loss: 1.3747 - val_accuracy: 0.5556
# Epoch 349/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 1.3709 - val_accuracy: 0.5556
# Epoch 350/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 1.3696 - val_accuracy: 0.5556
# Epoch 351/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0510 - accuracy: 1.0000 - val_loss: 1.3674 - val_accuracy: 0.5556
# Epoch 352/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0503 - accuracy: 1.0000 - val_loss: 1.3731 - val_accuracy: 0.5556
# Epoch 353/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0501 - accuracy: 1.0000 - val_loss: 1.3803 - val_accuracy: 0.5556
# Epoch 354/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0496 - accuracy: 1.0000 - val_loss: 1.3800 - val_accuracy: 0.5556
# Epoch 355/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0493 - accuracy: 1.0000 - val_loss: 1.3852 - val_accuracy: 0.5556
# Epoch 356/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0491 - accuracy: 1.0000 - val_loss: 1.3863 - val_accuracy: 0.5556
# Epoch 357/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0484 - accuracy: 1.0000 - val_loss: 1.3912 - val_accuracy: 0.5556
# Epoch 358/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0479 - accuracy: 1.0000 - val_loss: 1.3906 - val_accuracy: 0.5556
# Epoch 359/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0474 - accuracy: 1.0000 - val_loss: 1.3906 - val_accuracy: 0.5556
# Epoch 360/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0473 - accuracy: 1.0000 - val_loss: 1.3953 - val_accuracy: 0.5556
# Epoch 361/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0468 - accuracy: 1.0000 - val_loss: 1.4002 - val_accuracy: 0.5556
# Epoch 362/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0464 - accuracy: 1.0000 - val_loss: 1.3998 - val_accuracy: 0.5556
# Epoch 363/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0461 - accuracy: 1.0000 - val_loss: 1.4030 - val_accuracy: 0.5556
# Epoch 364/400
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0458 - accuracy: 1.0000 - val_loss: 1.4030 - val_accuracy: 0.5556
# Epoch 365/400
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0454 - accuracy: 1.0000 - val_loss: 1.4069 - val_accuracy: 0.5556
# Epoch 366/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0452 - accuracy: 1.0000 - val_loss: 1.4109 - val_accuracy: 0.5556
# Epoch 367/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 1.4112 - val_accuracy: 0.5556
# Epoch 368/400
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0443 - accuracy: 1.0000 - val_loss: 1.4153 - val_accuracy: 0.5556
# Epoch 369/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0442 - accuracy: 1.0000 - val_loss: 1.4128 - val_accuracy: 0.5556
# Epoch 370/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0440 - accuracy: 1.0000 - val_loss: 1.4138 - val_accuracy: 0.5556
# Epoch 371/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0433 - accuracy: 1.0000 - val_loss: 1.4155 - val_accuracy: 0.5556
# Epoch 372/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0433 - accuracy: 1.0000 - val_loss: 1.4133 - val_accuracy: 0.5556
# Epoch 373/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0428 - accuracy: 1.0000 - val_loss: 1.4169 - val_accuracy: 0.5556
# Epoch 374/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0423 - accuracy: 1.0000 - val_loss: 1.4180 - val_accuracy: 0.5556
# Epoch 375/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0421 - accuracy: 1.0000 - val_loss: 1.4208 - val_accuracy: 0.5556
# Epoch 376/400
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0419 - accuracy: 1.0000 - val_loss: 1.4188 - val_accuracy: 0.5556
# Epoch 377/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0413 - accuracy: 1.0000 - val_loss: 1.4222 - val_accuracy: 0.5556
# Epoch 378/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0411 - accuracy: 1.0000 - val_loss: 1.4262 - val_accuracy: 0.5556
# Epoch 379/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0407 - accuracy: 1.0000 - val_loss: 1.4310 - val_accuracy: 0.5556
# Epoch 380/400
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0405 - accuracy: 1.0000 - val_loss: 1.4338 - val_accuracy: 0.5556
# Epoch 381/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0402 - accuracy: 1.0000 - val_loss: 1.4345 - val_accuracy: 0.5556
# Epoch 382/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0400 - accuracy: 1.0000 - val_loss: 1.4366 - val_accuracy: 0.5556
# Epoch 383/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0395 - accuracy: 1.0000 - val_loss: 1.4376 - val_accuracy: 0.5556
# Epoch 384/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0392 - accuracy: 1.0000 - val_loss: 1.4389 - val_accuracy: 0.5556
# Epoch 385/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0392 - accuracy: 1.0000 - val_loss: 1.4399 - val_accuracy: 0.5556
# Epoch 386/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0386 - accuracy: 1.0000 - val_loss: 1.4437 - val_accuracy: 0.5556
# Epoch 387/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0383 - accuracy: 1.0000 - val_loss: 1.4448 - val_accuracy: 0.5556
# Epoch 388/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0384 - accuracy: 1.0000 - val_loss: 1.4442 - val_accuracy: 0.5556
# Epoch 389/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0379 - accuracy: 1.0000 - val_loss: 1.4455 - val_accuracy: 0.5556
# Epoch 390/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 1.4438 - val_accuracy: 0.5556
# Epoch 391/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0373 - accuracy: 1.0000 - val_loss: 1.4455 - val_accuracy: 0.5556
# Epoch 392/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 1.4467 - val_accuracy: 0.5556
# Epoch 393/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0369 - accuracy: 1.0000 - val_loss: 1.4527 - val_accuracy: 0.5556
# Epoch 394/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0364 - accuracy: 1.0000 - val_loss: 1.4536 - val_accuracy: 0.5556
# Epoch 395/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 1.4509 - val_accuracy: 0.5556
# Epoch 396/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0359 - accuracy: 1.0000 - val_loss: 1.4550 - val_accuracy: 0.5556
# Epoch 397/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0358 - accuracy: 1.0000 - val_loss: 1.4545 - val_accuracy: 0.5556
# Epoch 398/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0357 - accuracy: 1.0000 - val_loss: 1.4591 - val_accuracy: 0.5556
# Epoch 399/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 1.4600 - val_accuracy: 0.5556
# Epoch 400/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 1.4645 - val_accuracy: 0.5556

# %%
plt.figure()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(km.history['loss'])
plt.plot(km.history['val_loss'])
plt.legend(['Training', 'Validation'])

plt.figure()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(km.history['accuracy'])
plt.plot(km.history['val_accuracy'])
plt.legend(['Training', 'Validation'], loc='lower right')

# %%
#-- Generate predicted y values
y_pred_prob = keras_model.predict(preprocessor(X_test))

#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index= np.argmax(y_pred_prob, axis=1) # Predict

# extract correct prediction labels
prediction_labels = [y_test.columns[i] for i in prediction_column_index]

## Write code to show model performance by comparing prediction_labels with true labels
y_test_labels = y_test.idxmax(axis=1)
accuracy = accuracy_score(y_test_labels, prediction_labels)
print(f"Accuracy of the Keras model: {accuracy:.4f}")

report = classification_report(y_test_labels, prediction_labels)
print("Classification Report:\n", report)
# Out:
# 1/1 [==============================] - 0s 149ms/step
# Accuracy of the Keras model: 0.4737
# Classification Report:
#                precision    recall  f1-score   support
#
#      Average       0.00      0.00      0.00         4
#         High       0.60      0.60      0.60         5
#          Low       0.33      0.25      0.29         4
#    Very High       0.67      1.00      0.80         2
#     Very Low       0.50      0.75      0.60         4
#
#     accuracy                           0.47        19
#    macro avg       0.42      0.52      0.46        19
# weighted avg       0.40      0.47      0.43        19

# %% [markdown]
# We have tried many different architectures and number of epochs, and none of those improve the model. Adding more layers doesn't change much of the result, removing one drops the accuracy. Reducing the number of epochs reduces the accuracy on the test set too, despite signs of overfitting, and increasing it definitely overfit the model. Overall, we didn't find ways to compensate for the very bad results of the "Average" class, introducing weights based on the frequency of categories in the training dataset would be a good way to solve this issue.>

# %% [markdown]
# **Deep learning models are often considered 'black boxes' due to their complexity. Explore methods such as SHAP (SHapley Additive exPlanations) to explain your model's predictions. After applying one of these methods, do you feel it provides a clear and sufficient explanation of how your model makes decisions? How easy or difficult is it to justify your model's predictions using these techniques?**

# %%
import shap

explainer = shap.DeepExplainer(keras_model, preprocessor(X_train))

# compute SHAP values for the test set
shap_values = explainer.shap_values(preprocessor(X_test))
# Out:
# C:\Users\mathi\anaconda3\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\mathi\anaconda3\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(

# %%
# Average the absolute SHAP values across all instances for each feature
shap_values_combined = np.abs(shap_values[0])  # Use shap_values[0] for the first class (0 for binary classification)
mean_shap_values = np.mean(shap_values_combined, axis=1)  # Change axis=0 to axis=1

print(mean_shap_values.shape)  # This should now show the correct shape
# Out:
# (33,)

# %%
columns = preprocess.get_feature_names_out()

# Create a DataFrame for easier plotting
shap_df = pd.DataFrame({
    'Feature': columns,
    'Mean SHAP Value': mean_shap_values
})

# Sort the DataFrame by Mean SHAP Value
shap_df = shap_df.sort_values(by='Mean SHAP Value', ascending=True)

# Plot the final bar plot
plt.figure(figsize=(12, 12))
plt.barh(shap_df['Feature'], shap_df['Mean SHAP Value'], color='skyblue')
plt.xlabel('Mean SHAP Value')
plt.title('Mean SHAP Values for All Features')
plt.show()

# %% [markdown]
# Shap allows for some interpretability of the resuts. We can see which entry parameters are the most influent but doesn't give a lot more. It can be seen as insuficient, for instance we don't see how the different parameters interacts, and what could be a key combination of features.

# %% [markdown]
# # 7. Submission of final report and clean code to github
#
# [This is a final project you display on your GitHub to the World]
#
# **Instructions**
# - Make a new notebook, visualize any plots you found relevant
# - Reproduce the code you used for the best models and display results
# - Write what insights you found useful and what behaviours were observed
# - Make it in a style of a clean, succint report (within the .ipynb)
# - Upload this final report notebook to a new repository in your personal github account
# - Remember to paste the link of your final repo at the top of this notebook where asked
